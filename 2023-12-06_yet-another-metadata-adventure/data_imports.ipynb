# %%
#! python3
# Library of functions to load metadata from various places, and merge into unified patient, biosample tables.
# Usage: generate_biosample_table()
# Requires: 
# 
# Owen Chapman

import pandas as pd
import pathlib
import os

## Function to load metadata from the AmpliconClassifier results
## Get this file from /expanse/lustre/projects/csd677/collab/projects/pedpancan/AmpliconClassifier/batch/inputs
def get_pedpancan_biosamples_from_AC(include_x01=False,path='pedpancan_summary_map.txt'):
    path = pathlib.Path(path)
    df = pd.read_csv(path, sep='\t', header=None, index_col=0, names = ["biosample","file"])
    if not include_x01:
        df['firstletter']=df.index.map(lambda x: x[0])
        df = df[df.firstletter != 'P']
    return df.index
# Out:
# Index(['BS_85Y70BHE', 'BS_A9S5HT6P', 'BS_1EQGGHHQ', 'BS_BR1X3R68',
#        'BS_JDMM2XG4', 'BS_859AV1DB', 'BS_RCC7ZEC0', 'BS_9KDA3HG6',
#        'BS_E0S2Y0TS', 'BS_1C4WCNQF',
#        ...
#        'SJOS001101_M1', 'SJOS001130_D1', 'SJOS010_D', 'SJOS012_D',
#        'SJOS030876_D1', 'SJRHB012_D', 'SJST030043_D1', 'SJST030131_D1',
#        'SJST030383_D1', 'SJST030890_D1'],
#       dtype='object', name='biosample', length=1711)

# %%
## Functions to load metadata from the CAVATICA API. 
## See also 2023-11-27_cavatica-api/cavatica-api.ipynb
def import_x01_biosample_metadata(path="X01-biosample-metadata.tsv"):
    path = pathlib.Path(path)
    df = pd.read_csv(path, sep='\t',index_col=0)
    df["cohort"]="PBTA-X01"
    return df
def import_x00_biosample_metadata(path="X00-biosample-metadata.tsv"):
    df = import_x01_biosample_metadata(path)
    df["cohort"]="PBTA-X00"
    return df
def import_pnoc_biosample_metadata(path="PNOC-biosample-metadata.tsv"):
    df = import_x01_biosample_metadata(path)
    df["cohort"]="PNOC"
    return df
# Out:
#                            gender              race               ethnicity  \
# Kids First Biospecimen ID
# BS_8SYN7GXG                  Male             White  Not Hispanic or Latino
# BS_DRVEFVQ5                  Male  Reported Unknown        Reported Unknown
# BS_Y96RP1HJ                  Male  Reported Unknown        Reported Unknown
# BS_7GKF6M85                Female             Asian  Not Hispanic or Latino
# BS_169P1QCA                  Male             White  Not Hispanic or Latino
# ...                           ...               ...                     ...
# BS_VXDGXQKZ                Female  Reported Unknown        Reported Unknown
# BS_38CD519Z                  Male             Asian      Hispanic or Latino
# BS_4DQAQFQH                Female  Reported Unknown      Hispanic or Latino
# BS_TQ0J7WJQ                Female  Reported Unknown      Hispanic or Latino
# BS_5Z0GA574                Female             White  Not Hispanic or Latino
#
#                           Kids First Participant ID  \
# Kids First Biospecimen ID
# BS_8SYN7GXG                             PT_0MXPTTM3
# BS_DRVEFVQ5                             PT_1AAYYGGY
# BS_Y96RP1HJ                             PT_1AAYYGGY
# BS_7GKF6M85                             PT_1E3E6GMF
# BS_169P1QCA                             PT_1YQH5NSH
# ...                                             ...
# BS_VXDGXQKZ                             PT_VPEMAQBN
# BS_38CD519Z                             PT_W5GP3F6B
# BS_4DQAQFQH                             PT_WGVEF96B
# BS_TQ0J7WJQ                             PT_WGVEF96B
# BS_5Z0GA574                             PT_Y74CVASJ
#
#                                                                 disease_type  \
# Kids First Biospecimen ID
# BS_8SYN7GXG                                           Anaplastic Astrocytoma
# BS_DRVEFVQ5                                           Anaplastic Astrocytoma
# BS_Y96RP1HJ                                           Anaplastic Astrocytoma
# BS_7GKF6M85                                              Diffuse Astrocytoma
# BS_169P1QCA                Diffuse midline glioma; H3K27M mutant; WHO gra...
# ...                                                                      ...
# BS_VXDGXQKZ                                           Anaplastic Astrocytoma
# BS_38CD519Z                Diffuse midline glioma; H3K27M mutant; WHO gra...
# BS_4DQAQFQH                                              Diffuse Astrocytoma
# BS_TQ0J7WJQ                                              Diffuse Astrocytoma
# BS_5Z0GA574                                                     Glioblastoma
#
#                                          sample_id Tumor Descriptor  \
# Kids First Biospecimen ID
# BS_8SYN7GXG                 7316-3220-T-A09410.WGS        Diagnosis
# BS_DRVEFVQ5                 7316-4996-T-A14710.WGS        Diagnosis
# BS_Y96RP1HJ                 7316-4996-T-A14709.WGS        Diagnosis
# BS_7GKF6M85                 7316-3224-T-A09985.WGS        Diagnosis
# BS_169P1QCA                7316-5922-T-SF11653.WGS        Diagnosis
# ...                                            ...              ...
# BS_VXDGXQKZ                7316-3235-T-SF10693.WGS        Diagnosis
# BS_38CD519Z                 7316-5003-T-A16915.WGS        Diagnosis
# BS_4DQAQFQH                7316-4446-T-SF10438.WGS        Diagnosis
# BS_TQ0J7WJQ                 7316-3219-T-A08958.WGS        Diagnosis
# BS_5Z0GA574                 7316-5002-T-A16538.WGS        Diagnosis
#
#                           primary_site  age_at_diagnosis   case_id  \
# Kids First Biospecimen ID
# BS_8SYN7GXG                 Brain Stem              9425  C3080535
# BS_DRVEFVQ5                 Brain Stem              4608  C3079920
# BS_Y96RP1HJ                 Brain Stem              4608  C3079920
# BS_7GKF6M85                 Brain Stem              2211  C3081150
# BS_169P1QCA                 Brain Stem              2520  C3093819
# ...                                ...               ...       ...
# BS_VXDGXQKZ                 Brain Stem              1709  C3078444
# BS_38CD519Z                 Brain Stem              2459  C3092712
# BS_4DQAQFQH                 Brain Stem              2853  C3080043
# BS_TQ0J7WJQ                 Brain Stem              2853  C3080043
# BS_5Z0GA574                 Brain Stem              1717  C3081519
#
#                                                        WGS_UUID cohort
# Kids First Biospecimen ID
# BS_8SYN7GXG                3526c1ab-a793-4c5f-9576-d922835dbd78   PNOC
# BS_DRVEFVQ5                d182b330-17aa-47de-9c3a-5fee37a4ee33   PNOC
# BS_Y96RP1HJ                e3629477-53cc-40c6-a4f6-72ecc70a4451   PNOC
# BS_7GKF6M85                2865b67b-1458-492e-a39e-57900f34da9f   PNOC
# BS_169P1QCA                64b37304-0567-4f2c-9790-b3cce218955c   PNOC
# ...                                                         ...    ...
# BS_VXDGXQKZ                7ad281cf-82c0-46b9-9a23-8348d623ba77   PNOC
# BS_38CD519Z                80fd23ab-de59-45da-80f6-49af162fe982   PNOC
# BS_4DQAQFQH                3d9ec140-cf1f-48e0-b4bd-d9ae775b29b0   PNOC
# BS_TQ0J7WJQ                c2e040bd-64b7-4928-8428-1da909cb2873   PNOC
# BS_5Z0GA574                a7eaf642-8f59-4b80-a1c1-709afc030e16   PNOC
#
# [72 rows x 12 columns]

# %%
def clean_cavatica_biosample_metadata(df):
    '''
    Clean known errors in the x01 metadata, and unify ontologies.
    '''
    # remove suffix from pnoc sample ids
    df.sample_id = df.sample_id.map(lambda x: '-'.join(x.split('-')[:2]) if x.startswith("7316-") else x)
    
    df = df.replace({
        'Tumor Descriptor':{
            "initial CNS Tumor": "Diagnosis",
            "Not Applicable":None,
            "Unavailable":None,
            "Initial CNS Tumor": "Diagnosis",
            "Progressive Disease Post-Mortem":"Progressive",
        },
        'gender':{
            "Not Reported":None
        }
    })
    # Correct suspected errors
    df.loc["BS_6Z213H2V","Tumor Descriptor"] = "Progressive" # This tumor was resected 175 days after the initial tumor resection.
    df.loc["BS_1135HC0V","Tumor Descriptor"] = "Second Malignancy" # This dysplasia was diagnosed 574 days after the first tumor was resected, in a new location.
    df.loc["BS_ZS1QRMXS","Tumor Descriptor"] = "Progressive" # Tumor resected 128 days after previous resection.
    df.loc["BS_FVYBGMG1","Tumor Descriptor"] = "Progressive" # Tumor resected 107 days after previous resection.
    df.loc["BS_5J5VH3X0","Tumor Descriptor"] = "Progressive" # Biopsied 240 days after previous biopsy.
    df.loc["BS_E9M7TDB6","Tumor Descriptor"] = "Progressive" # Second resection in different location 112 days after previous resection.
    df.loc["BS_5XZP7F4Q","Tumor Descriptor"] = "Progressive" # Second resection 1845 days after previous
    df.loc["BS_EXTEGB51","Tumor Descriptor"] = "Progressive" # Third resection 1922 days after previous
    df.loc["BS_93BV8AY9","Tumor Descriptor"] = "Second Malignancy" # Second diagnosis 2975 days after initial.
    df.loc["BS_CRKBDAYZ","Tumor Descriptor"] = "Progressive" # Series of progressive diagnoses long after initial.
    df.loc["BS_B4DY7ET3","Tumor Descriptor"] = "Progressive" # Second resection 119 days after previous.
    return df
# Out:
#                            gender   race               ethnicity  \
# Kids First Biospecimen ID
# BS_92T7PSY6                  Male  White  Not Hispanic or Latino
# BS_T6A1KCT6                  Male  Asian  Not Hispanic or Latino
# BS_Q3H2JNNM                Female  White  Not Hispanic or Latino
# BS_MQFW7E1K                Female  Other      Hispanic or Latino
# BS_VGP89Y0H                  Male  Other            Not Reported
# ...                           ...    ...                     ...
# BS_5XZP7F4Q                   NaN    NaN                     NaN
# BS_EXTEGB51                   NaN    NaN                     NaN
# BS_93BV8AY9                   NaN    NaN                     NaN
# BS_CRKBDAYZ                   NaN    NaN                     NaN
# BS_B4DY7ET3                   NaN    NaN                     NaN
#
#                           Kids First Participant ID  \
# Kids First Biospecimen ID
# BS_92T7PSY6                             PT_01SH4F1X
# BS_T6A1KCT6                             PT_02QZ7Z0H
# BS_Q3H2JNNM                             PT_0324HWD5
# BS_MQFW7E1K                             PT_0449KSQ3
# BS_VGP89Y0H                             PT_047YGDRW
# ...                                             ...
# BS_5XZP7F4Q                                     NaN
# BS_EXTEGB51                                     NaN
# BS_93BV8AY9                                     NaN
# BS_CRKBDAYZ                                     NaN
# BS_B4DY7ET3                                     NaN
#
#                                                                 disease_type  \
# Kids First Biospecimen ID
# BS_92T7PSY6                                                    Ganglioglioma
# BS_T6A1KCT6                                                         Teratoma
# BS_Q3H2JNNM                 High-grade glioma/astrocytoma (WHO grade III/IV)
# BS_MQFW7E1K                Other;Low-grade glioma/astrocytoma (WHO grade ...
# BS_VGP89Y0H                    Low-grade glioma/astrocytoma (WHO grade I/II)
# ...                                                                      ...
# BS_5XZP7F4Q                                                              NaN
# BS_EXTEGB51                                                              NaN
# BS_93BV8AY9                                                              NaN
# BS_CRKBDAYZ                                                              NaN
# BS_B4DY7ET3                                                              NaN
#
#                            sample_id   Tumor Descriptor  \
# Kids First Biospecimen ID
# BS_92T7PSY6                7316-6365          Diagnosis
# BS_T6A1KCT6                7316-3804          Diagnosis
# BS_Q3H2JNNM                7316-7091          Diagnosis
# BS_MQFW7E1K                7316-6384          Diagnosis
# BS_VGP89Y0H                7316-6811          Diagnosis
# ...                              ...                ...
# BS_5XZP7F4Q                      NaN        Progressive
# BS_EXTEGB51                      NaN        Progressive
# BS_93BV8AY9                      NaN  Second Malignancy
# BS_CRKBDAYZ                      NaN        Progressive
# BS_B4DY7ET3                      NaN        Progressive
#
#                                          primary_site  age_at_diagnosis  \
# Kids First Biospecimen ID
# BS_92T7PSY6                             Temporal Lobe            3838.0
# BS_T6A1KCT6                              Pineal Gland             632.0
# BS_Q3H2JNNM                             Temporal Lobe            3121.0
# BS_MQFW7E1K                              Frontal Lobe            3900.0
# BS_VGP89Y0H                Cerebellum/Posterior Fossa            1258.0
# ...                                               ...               ...
# BS_5XZP7F4Q                                       NaN               NaN
# BS_EXTEGB51                                       NaN               NaN
# BS_93BV8AY9                                       NaN               NaN
# BS_CRKBDAYZ                                       NaN               NaN
# BS_B4DY7ET3                                       NaN               NaN
#
#                           Kids First Biospecimen ID Normal   case_id  \
# Kids First Biospecimen ID
# BS_92T7PSY6                                    BS_SP07ABJ6  C2578326
# BS_T6A1KCT6                                    BS_3A20RBVE   C976620
# BS_Q3H2JNNM                                    BS_PCFP168F  C2857659
# BS_MQFW7E1K                                    BS_CZ1T9EBV  C3224937
# BS_VGP89Y0H                                    BS_8QKDGV8X  C3550764
# ...                                                    ...       ...
# BS_5XZP7F4Q                                            NaN       NaN
# BS_EXTEGB51                                            NaN       NaN
# BS_93BV8AY9                                            NaN       NaN
# BS_CRKBDAYZ                                            NaN       NaN
# BS_B4DY7ET3                                            NaN       NaN
#
#                                                        WGS_UUID    cohort
# Kids First Biospecimen ID
# BS_92T7PSY6                afe1b9a2-5869-43c4-a56f-6528440436ba  PBTA-X01
# BS_T6A1KCT6                b166a462-a3b9-4a84-902f-fee597a39cd5  PBTA-X01
# BS_Q3H2JNNM                1f5badfa-8eb1-4a45-8cde-c2ca3d010cf8  PBTA-X01
# BS_MQFW7E1K                db1e69ed-f682-41a8-9c0f-a01cdfa6013e  PBTA-X01
# BS_VGP89Y0H                b8ae55bb-9e39-44bc-9062-6634fc7d8894  PBTA-X01
# ...                                                         ...       ...
# BS_5XZP7F4Q                                                 NaN       NaN
# BS_EXTEGB51                                                 NaN       NaN
# BS_93BV8AY9                                                 NaN       NaN
# BS_CRKBDAYZ                                                 NaN       NaN
# BS_B4DY7ET3                                                 NaN       NaN
#
# [1517 rows x 13 columns]

# %%
## Function to compile CAVATICA metatdata for all CBTN samples in our cohort.
def import_cbtn_biosample_metadata(include_X01=False):
    if include_X01:
        df = pd.concat([import_x00_biosample_metadata(),import_x01_biosample_metadata(),import_pnoc_biosample_metadata()])
    else:
        df = pd.concat([import_x00_biosample_metadata(),import_pnoc_biosample_metadata()])
    cohort = get_pedpancan_biosamples_from_AC()
    df = df[df.index.isin(cohort)]
    df = clean_cavatica_biosample_metadata(df)
    return df
# Out:
#                            gender                       race  \
# Kids First Biospecimen ID
# BS_K07KNTFY                  Male                      White
# BS_AQMKA8NC                  Male                      White
# BS_TE8QFF7T                  Male                      White
# BS_2VB8649B                  Male  Black or African American
# BS_5TT6TT4K                  Male  Black or African American
# ...                           ...                        ...
# BS_VXDGXQKZ                Female           Reported Unknown
# BS_38CD519Z                  Male                      Asian
# BS_4DQAQFQH                Female           Reported Unknown
# BS_TQ0J7WJQ                Female           Reported Unknown
# BS_5Z0GA574                Female                      White
#
#                                         ethnicity Kids First Participant ID  \
# Kids First Biospecimen ID
# BS_K07KNTFY                Not Hispanic or Latino               PT_00G007DM
# BS_AQMKA8NC                Not Hispanic or Latino               PT_00G007DM
# BS_TE8QFF7T                Not Hispanic or Latino               PT_01MZ62KG
# BS_2VB8649B                         Not Available               PT_02J5CWN5
# BS_5TT6TT4K                         Not Available               PT_02J5CWN5
# ...                                           ...                       ...
# BS_VXDGXQKZ                      Reported Unknown               PT_VPEMAQBN
# BS_38CD519Z                    Hispanic or Latino               PT_W5GP3F6B
# BS_4DQAQFQH                    Hispanic or Latino               PT_WGVEF96B
# BS_TQ0J7WJQ                    Hispanic or Latino               PT_WGVEF96B
# BS_5Z0GA574                Not Hispanic or Latino               PT_Y74CVASJ
#
#                                                                 disease_type  \
# Kids First Biospecimen ID
# BS_K07KNTFY                                                            Other
# BS_AQMKA8NC                                                            Other
# BS_TE8QFF7T                                                    Pineoblastoma
# BS_2VB8649B                    Low-grade glioma/astrocytoma (WHO grade I/II)
# BS_5TT6TT4K                    Low-grade glioma/astrocytoma (WHO grade I/II)
# ...                                                                      ...
# BS_VXDGXQKZ                                           Anaplastic Astrocytoma
# BS_38CD519Z                Diffuse midline glioma; H3K27M mutant; WHO gra...
# BS_4DQAQFQH                                              Diffuse Astrocytoma
# BS_TQ0J7WJQ                                              Diffuse Astrocytoma
# BS_5Z0GA574                                                     Glioblastoma
#
#                            sample_id Tumor Descriptor  \
# Kids First Biospecimen ID
# BS_K07KNTFY                 7316-272        Diagnosis
# BS_AQMKA8NC                7316-2577       Recurrence
# BS_TE8QFF7T                 7316-447      Progressive
# BS_2VB8649B                7316-2989        Diagnosis
# BS_5TT6TT4K                 7316-898      Progressive
# ...                              ...              ...
# BS_VXDGXQKZ                7316-3235        Diagnosis
# BS_38CD519Z                7316-5003        Diagnosis
# BS_4DQAQFQH                7316-4446        Diagnosis
# BS_TQ0J7WJQ                7316-3219        Diagnosis
# BS_5Z0GA574                7316-5002        Diagnosis
#
#                                                  primary_site  \
# Kids First Biospecimen ID
# BS_K07KNTFY                        Cerebellum/Posterior Fossa
# BS_AQMKA8NC                        Cerebellum/Posterior Fossa
# BS_TE8QFF7T                        Cerebellum/Posterior Fossa
# BS_2VB8649B                Suprasellar/Hypothalamic/Pituitary
# BS_5TT6TT4K                Suprasellar/Hypothalamic/Pituitary
# ...                                                       ...
# BS_VXDGXQKZ                                        Brain Stem
# BS_38CD519Z                                        Brain Stem
# BS_4DQAQFQH                                        Brain Stem
# BS_TQ0J7WJQ                                        Brain Stem
# BS_5Z0GA574                                        Brain Stem
#
#                            age_at_diagnosis  Kids First Biospecimen ID Normal  \
# Kids First Biospecimen ID
# BS_K07KNTFY                             464                               NaN
# BS_AQMKA8NC                            3178                               NaN
# BS_TE8QFF7T                             546                               NaN
# BS_2VB8649B                            2223                               NaN
# BS_5TT6TT4K                            3722                               NaN
# ...                                     ...                               ...
# BS_VXDGXQKZ                            1709                               NaN
# BS_38CD519Z                            2459                               NaN
# BS_4DQAQFQH                            2853                               NaN
# BS_TQ0J7WJQ                            2853                               NaN
# BS_5Z0GA574                            1717                               NaN
#
#                             case_id                              WGS_UUID  \
# Kids First Biospecimen ID
# BS_K07KNTFY                  C27429  7b06bec0-c64a-4df4-8237-d07de0a5df42
# BS_AQMKA8NC                  C27429  9ba06668-759e-440c-a22f-957df52dae06
# BS_TE8QFF7T                  C92004  bd68f356-781e-49d8-a5ff-ec6c12514dc1
# BS_2VB8649B                  C90159  3cdb9fca-94cf-4938-9d20-cd1b0c59f6a0
# BS_5TT6TT4K                  C90159  2c620221-1561-4073-8558-f81e4b3c9dcc
# ...                             ...                                   ...
# BS_VXDGXQKZ                C3078444  7ad281cf-82c0-46b9-9a23-8348d623ba77
# BS_38CD519Z                C3092712  80fd23ab-de59-45da-80f6-49af162fe982
# BS_4DQAQFQH                C3080043  3d9ec140-cf1f-48e0-b4bd-d9ae775b29b0
# BS_TQ0J7WJQ                C3080043  c2e040bd-64b7-4928-8428-1da909cb2873
# BS_5Z0GA574                C3081519  a7eaf642-8f59-4b80-a1c1-709afc030e16
#
#                              cohort
# Kids First Biospecimen ID
# BS_K07KNTFY                PBTA-X00
# BS_AQMKA8NC                PBTA-X00
# BS_TE8QFF7T                PBTA-X00
# BS_2VB8649B                PBTA-X00
# BS_5TT6TT4K                PBTA-X00
# ...                             ...
# BS_VXDGXQKZ                    PNOC
# BS_38CD519Z                    PNOC
# BS_4DQAQFQH                    PNOC
# BS_TQ0J7WJQ                    PNOC
# BS_5Z0GA574                    PNOC
#
# [994 rows x 13 columns]

# %%
## Functions to open & preprocess opentarget histology data.
## Get histologies.tsv from https://github.com/d3b-center/OpenPedCan-analysis/blob/dev/analyses/molecular-subtyping-integrate/results/histologies.tsv
df = pd.read_csv("pedpancan_histologies.tsv", sep='delimiter', header=None)
def clean_opentarget_histologies_files(df):
    cohort = import_cbtn_biosample_metadata()
    df = df[df.sample_id.isin(cohort.sample_id)]
    df = df[df.sample_type == 'Tumor'] # Drop normals
    df = df[df.composition != 'Derived Cell Line'] # Drop cell lines
    df = df[df.experimental_strategy != "Targeted Sequencing"] # these metadata are very different
    df = df.drop(["RNA_library","seq_center","pathology_free_text_diagnosis","gtex_group","gtex_subgroup","normal_fraction",
                  "cell_line_composition","cell_line_passage","tumor_fraction_RFpurify_ABSOLUTE",
                  "tumor_fraction_RFpurify_ESTIMATE","tumor_fraction_LUMP","dkfz_v12_methylation_mgmt_status",
                  "dkfz_v12_methylation_mgmt_estimated","integrated_diagnosis",
                  "tumor_fraction","tumor_ploidy","cohort"],axis=1) # drop columns we know we don't want
    df = df.replace({
        'composition':{
            "Not Available": None,
        },
        'extent_of_tumor_resection':{
            "Not Reported":None,
            'Unavailable':None,
            'Not Applicable':None
        },
    })
    
    # correct known errors
    df.loc["BS_K14VJ1E3","age_at_diagnosis_days"] = 2778
    df = df.drop(["BS_03G6PJKJ","BS_HJJPT3NR","BS_15R0SQRN","BS_GGDMSB26","BS_VQGR0D61"]) # lots of biosamples for the same tumor at the same timepoint
    
    # Propagate metadata from the same sample_id
    g = df.groupby('sample_id')
    df = []
    for name, group in g:
        columns = [col for col in group.columns if col not in ['sample_id','aliquot_id','experimental_strategy']]
        for column in columns:
            unique_values = group[column].dropna().unique()
            if len(unique_values) == 0:
                continue
            elif len(unique_values) == 1:
                non_na_value = unique_values[0]
                group[column].fillna(non_na_value, inplace=True)
            else:
                print(f"Warning: The column '{column}' for sample {name} differs between CAVATICA and opentarget annotations.")
        group=group.sort_values('experimental_strategy')
        df.append(group)
    df = pd.concat(df)
    
    # Add entries missing a KF biospecimen ID, but with a matching external biosample id.
    missing_bs = (cohort[~cohort.index.isin(df.index)]["sample_id"]).sort_values()
    print(f"{len(missing_bs)} KF biospecimens missing from the opentarget histologies table...")
    missing_bs = missing_bs[missing_bs.isin(df.sample_id)]
    print(f"found {len(missing_bs)} matching external sample IDs, adding to table...")
    newdf = []
    for biospecimen, sample in missing_bs.items():
        newentry=df[df.sample_id==sample].iloc[0]
        newentry.name = biospecimen
        newdf.append(newentry)
    newdf = pd.DataFrame(newdf)
    df = pd.concat([df,newdf])
    
    # Subset our cohort
    df = df[df.index.isin(cohort.index)]
    return df
# Out:
# /var/folders/vv/261hv1sn1h36hvx1wc1cv9w40000gp/T/ipykernel_85943/38724199.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv("pedpancan_histologies.tsv", sep='delimiter', header=None)

# %%
def import_opentarget_histologies_files(path='owen_histologies.tsv'):
    '''
    Get this file from /Users/ochapman/Library/CloudStorage/OneDrive-SanfordBurnhamPrebysMedicalDiscoveryInstitute/projects/2023-pedpancan/data/opentarget/histologies.tsv
    '''
    path = pathlib.Path(path)
    df = pd.read_csv(path,sep='\t',index_col=0)
    df = clean_opentarget_histologies_files(df)
    return df
# Out:
# /var/folders/vv/261hv1sn1h36hvx1wc1cv9w40000gp/T/ipykernel_85943/2192161946.py:6: DtypeWarning: Columns (1,21,24,25,26,27,33,36,37,41,43,45,47,48,49,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path,sep='\t',index_col=0)
# Warning: The column 'harmonized_diagnosis' for sample 7316-1101 differs between CAVATICA and opentarget annotations.
# Warning: The column 'harmonized_diagnosis' for sample 7316-2935 differs between CAVATICA and opentarget annotations.
# Warning: The column 'tumor_descriptor' for sample 7316-3217 differs between CAVATICA and opentarget annotations.
# Warning: The column 'primary_site' for sample 7316-3229 differs between CAVATICA and opentarget annotations.
# Warning: The column 'age_at_diagnosis_days' for sample 7316-323 differs between CAVATICA and opentarget annotations.
# Warning: The column 'primary_site' for sample 7316-3230 differs between CAVATICA and opentarget annotations.
# Warning: The column 'CNS_region' for sample 7316-3230 differs between CAVATICA and opentarget annotations.
# Warning: The column 'primary_site' for sample 7316-3231 differs between CAVATICA and opentarget annotations.
# Warning: The column 'harmonized_diagnosis' for sample 7316-3295 differs between CAVATICA and opentarget annotations.
# Warning: The column 'harmonized_diagnosis' for sample 7316-3632 differs between CAVATICA and opentarget annotations.
# Warning: The column 'harmonized_diagnosis' for sample 7316-4062 differs between CAVATICA and opentarget annotations.
# Warning: The column 'harmonized_diagnosis' for sample 7316-921 differs between CAVATICA and opentarget annotations.
# 53 KF biospecimens missing from the opentarget histologies table...
# found 41 matching external sample IDs, adding to table...
#              sample_id aliquot_id Kids_First_Participant_ID  \
# BS_1RFBH1SP    7316-10     717017               PT_K8ZV7APT
# BS_SFZ3A07S   7316-100      67852               PT_6TZR2DH1
# BS_4RS1SC48   7316-101     588044               PT_CWD717Q0
# BS_MRX1SPFB   7316-104     717047               PT_H024RK87
# BS_A9S5HT6P  7316-1069     717042               PT_9XAA8PF6
# ...                ...        ...                       ...
# BS_FJEZ3ASV   7316-913    1108019               PT_4347ZBEX
# BS_5DHZ0T1A   7316-925    1112611               PT_3HRS5CWF
# BS_W37QBA12   7316-931    1112899               PT_XA98HG1C
# BS_ZVM1B6BF    7316-95     608916               PT_9S6WMQ92
# BS_6D37YSGS   7316-968    1030646               PT_62VNQ8C4
#
#             experimental_strategy sample_type   composition  \
# BS_1RFBH1SP                   WGS       Tumor  Solid Tissue
# BS_SFZ3A07S                   WGS       Tumor  Solid Tissue
# BS_4RS1SC48                   WGS       Tumor  Solid Tissue
# BS_MRX1SPFB                   WGS       Tumor  Solid Tissue
# BS_A9S5HT6P                   WGS       Tumor  Solid Tissue
# ...                           ...         ...           ...
# BS_FJEZ3ASV           Methylation       Tumor  Solid Tissue
# BS_5DHZ0T1A           Methylation       Tumor  Solid Tissue
# BS_W37QBA12           Methylation       Tumor  Solid Tissue
# BS_ZVM1B6BF               RNA-Seq       Tumor  Solid Tissue
# BS_6D37YSGS               RNA-Seq       Tumor  Solid Tissue
#
#               tumor_descriptor  \
# BS_1RFBH1SP  Initial CNS Tumor
# BS_SFZ3A07S  Initial CNS Tumor
# BS_4RS1SC48  Initial CNS Tumor
# BS_MRX1SPFB         Recurrence
# BS_A9S5HT6P  Initial CNS Tumor
# ...                        ...
# BS_FJEZ3ASV  Second Malignancy
# BS_5DHZ0T1A  Initial CNS Tumor
# BS_W37QBA12  Initial CNS Tumor
# BS_ZVM1B6BF        Progressive
# BS_6D37YSGS  Initial CNS Tumor
#
#                                                   primary_site  \
# BS_1RFBH1SP                     Spinal Cord- Lumbar/Thecal Sac
# BS_SFZ3A07S                 Suprasellar/Hypothalamic/Pituitary
# BS_4RS1SC48                                      Temporal Lobe
# BS_MRX1SPFB  Brain Stem- Midbrain/Tectum;Pineal Gland;Thala...
# BS_A9S5HT6P                 Suprasellar/Hypothalamic/Pituitary
# ...                                                        ...
# BS_FJEZ3ASV                        Parietal Lobe;Temporal Lobe
# BS_5DHZ0T1A                         Cerebellum/Posterior Fossa
# BS_W37QBA12                         Cerebellum/Posterior Fossa
# BS_ZVM1B6BF                         Cerebellum/Posterior Fossa
# BS_6D37YSGS   Cerebellum/Posterior Fossa;Spinal Cord- Cervical
#
#             reported_gender                       race  ...  \
# BS_1RFBH1SP          Female  Black or African American  ...
# BS_SFZ3A07S          Female  Black or African American  ...
# BS_4RS1SC48            Male  Black or African American  ...
# BS_MRX1SPFB            Male                      Asian  ...
# BS_A9S5HT6P          Female                      White  ...
# ...                     ...                        ...  ...
# BS_FJEZ3ASV          Female                      White  ...
# BS_5DHZ0T1A          Female                      White  ...
# BS_W37QBA12            Male                      White  ...
# BS_ZVM1B6BF          Female                      White  ...
# BS_6D37YSGS          Female                      White  ...
#
#             dkfz_v11_methylation_subclass_score  \
# BS_1RFBH1SP                               0.598
# BS_SFZ3A07S                               0.668
# BS_4RS1SC48                               0.479
# BS_MRX1SPFB                               0.230
# BS_A9S5HT6P                                 NaN
# ...                                         ...
# BS_FJEZ3ASV                               0.999
# BS_5DHZ0T1A                               0.993
# BS_W37QBA12                               0.906
# BS_ZVM1B6BF                                 NaN
# BS_6D37YSGS                                 NaN
#
#              dkfz_v12_methylation_subclass  \
# BS_1RFBH1SP                      NFIB_PLEX
# BS_SFZ3A07S                        CPH_ADM
# BS_4RS1SC48                        PA_CORT
# BS_MRX1SPFB                       GCT_TERA
# BS_A9S5HT6P                            NaN
# ...                                    ...
# BS_FJEZ3ASV                   pedHGG_RTK1C
# BS_5DHZ0T1A                         PA_INF
# BS_W37QBA12                       MB_SHH_3
# BS_ZVM1B6BF                            NaN
# BS_6D37YSGS                            NaN
#
#             dkfz_v12_methylation_subclass_score   molecular_subtype  \
# BS_1RFBH1SP                            0.507953                 NaN
# BS_SFZ3A07S                            0.580744        CRANIO, ADAM
# BS_4RS1SC48                            0.825647     GNG, other MAPK
# BS_MRX1SPFB                            0.972105                 NaN
# BS_A9S5HT6P                                 NaN                 NaN
# ...                                         ...                 ...
# BS_FJEZ3ASV                            0.982681    HGG, H3 wildtype
# BS_5DHZ0T1A                            0.999797  LGG, KIAA1549-BRAF
# BS_W37QBA12                            0.480522             MB, SHH
# BS_ZVM1B6BF                                 NaN             MB, SHH
# BS_6D37YSGS                                 NaN             MB, SHH
#
#                                                          Notes  \
# BS_1RFBH1SP                                                NaN
# BS_SFZ3A07S                   Updated via OpenPedCan subtyping
# BS_4RS1SC48                   Updated via OpenPedCan subtyping
# BS_MRX1SPFB                                                NaN
# BS_A9S5HT6P                                                NaN
# ...                                                        ...
# BS_FJEZ3ASV                   Updated via OpenPedCan subtyping
# BS_5DHZ0T1A                   Updated via OpenPedCan subtyping
# BS_W37QBA12  Subtype based on prediction;Updated via OpenPe...
# BS_ZVM1B6BF  Subtype based on prediction;Updated via OpenPe...
# BS_6D37YSGS  Subtype based on prediction;Updated via OpenPe...
#
#                                         harmonized_diagnosis  \
# BS_1RFBH1SP                           Neurofibroma/Plexiform
# BS_SFZ3A07S               Adamantinomatous craniopharyngioma
# BS_4RS1SC48                        Ganglioglioma, other MAPK
# BS_MRX1SPFB       Non-germinomatous germ cell tumor;Teratoma
# BS_A9S5HT6P                                          Adenoma
# ...                                                      ...
# BS_FJEZ3ASV  High-grade glioma, IDH-wildtype and H3-wildtype
# BS_5DHZ0T1A                  Low-grade glioma, KIAA1549-BRAF
# BS_W37QBA12                   Medulloblastoma, SHH-activated
# BS_ZVM1B6BF                   Medulloblastoma, SHH-activated
# BS_6D37YSGS                   Medulloblastoma, SHH-activated
#
#              molecular_subtype_methyl  \
# BS_1RFBH1SP                       NaN
# BS_SFZ3A07S                       NaN
# BS_4RS1SC48                 GNT, MAPK
# BS_MRX1SPFB                       NaN
# BS_A9S5HT6P                       NaN
# ...                               ...
# BS_FJEZ3ASV          HGG, H3 wildtype
# BS_5DHZ0T1A                 LGG, FGFR
# BS_W37QBA12                       NaN
# BS_ZVM1B6BF                       NaN
# BS_6D37YSGS                       NaN
#
#                                            broad_histology    short_histology  \
# BS_1RFBH1SP         Tumor of cranial and paraspinal nerves       Neurofibroma
# BS_SFZ3A07S                        Tumors of sellar region  Craniopharyngioma
# BS_4RS1SC48                     Low-grade astrocytic tumor      Ganglioglioma
# BS_MRX1SPFB                                Germ cell tumor    Germ cell tumor
# BS_A9S5HT6P                                   Benign tumor            Adenoma
# ...                                                    ...                ...
# BS_FJEZ3ASV  Diffuse astrocytic and oligodendroglial tumor               HGAT
# BS_5DHZ0T1A                     Low-grade astrocytic tumor               LGAT
# BS_W37QBA12                                Embryonal tumor    Medulloblastoma
# BS_ZVM1B6BF                                Embryonal tumor    Medulloblastoma
# BS_6D37YSGS                                Embryonal tumor    Medulloblastoma
#
#                                    cancer_group
# BS_1RFBH1SP              Neurofibroma/Plexiform
# BS_SFZ3A07S  Adamantinomatous Craniopharyngioma
# BS_4RS1SC48                       Ganglioglioma
# BS_MRX1SPFB                                 NaN
# BS_A9S5HT6P                                 NaN
# ...                                         ...
# BS_FJEZ3ASV                   High-grade glioma
# BS_5DHZ0T1A                    Low-grade glioma
# BS_W37QBA12                     Medulloblastoma
# BS_ZVM1B6BF                     Medulloblastoma
# BS_6D37YSGS                     Medulloblastoma
#
# [982 rows x 37 columns]

# %%
def import_pedcbioportal_metadata(path="openpbta-biosample-metadata.tsv"):
    path = pathlib.Path(path)
    df = pd.read_csv(path, sep='\t',index_col=0)
    return df
# Out:
#               sampleId                 CANCER_TYPE  \
# patientId
# PT_00G007DM  7316-2577             Embryonal tumor
# PT_00G007DM   7316-272             Embryonal tumor
# PT_01MZ62KG   7316-447             Embryonal tumor
# PT_02J5CWN5  7316-2989  Low-grade astrocytic tumor
# PT_02J5CWN5   7316-898  Low-grade astrocytic tumor
# ...                ...                         ...
# PT_ZZRBX5JT  7316-2661             Ependymal tumor
# PT_ZZRBX5JT  7316-3319             Ependymal tumor
# PT_ZZRBX5JT   7316-496             Ependymal tumor
# PT_ZZTQQVCT  7316-2723  Low-grade astrocytic tumor
# PT_ZZWYKZZ8  7316-2758             Ependymal tumor
#
#                                           CANCER_TYPE_DETAILED  \
# patientId
# PT_00G007DM                           CNS Embryonal tumor, NOS
# PT_00G007DM  Embryonal tumor with multilayer rosettes, C19M...
# PT_01MZ62KG  Embryonal tumor with multilayer rosettes, C19M...
# PT_02J5CWN5                 Low-grade glioma/astrocytoma, FGFR
# PT_02J5CWN5             Low-grade glioma/astrocytoma, wildtype
# ...                                                        ...
# PT_ZZRBX5JT                                         Ependymoma
# PT_ZZRBX5JT                                         Ependymoma
# PT_ZZRBX5JT                                         Ependymoma
# PT_ZZTQQVCT             Low-grade glioma/astrocytoma, wildtype
# PT_ZZWYKZZ8                                         Ependymoma
#
#                   CNS_REGION EXPERIMENTAL_STRATEGY  \
# patientId
# PT_00G007DM  Posterior fossa           WGS;RNA-Seq
# PT_00G007DM  Posterior fossa           WGS;RNA-Seq
# PT_01MZ62KG  Posterior fossa           RNA-Seq;WGS
# PT_02J5CWN5      Suprasellar           WGS;RNA-Seq
# PT_02J5CWN5      Suprasellar           RNA-Seq;WGS
# ...                      ...                   ...
# PT_ZZRBX5JT  Posterior fossa           RNA-Seq;WGS
# PT_ZZRBX5JT            Spine           WGS;RNA-Seq
# PT_ZZRBX5JT       Ventricles           WGS;RNA-Seq
# PT_ZZTQQVCT  Posterior fossa           WGS;RNA-Seq
# PT_ZZWYKZZ8            Mixed           WGS;RNA-Seq
#
#               EXTENT_OF_TUMOR_RESECTION  \
# patientId
# PT_00G007DM  Gross/Near total resection
# PT_00G007DM  Gross/Near total resection
# PT_01MZ62KG           Partial resection
# PT_02J5CWN5           Partial resection
# PT_02J5CWN5           Partial resection
# ...                                 ...
# PT_ZZRBX5JT  Gross/Near total resection
# PT_ZZRBX5JT  Gross/Near total resection
# PT_ZZRBX5JT  Gross/Near total resection
# PT_ZZTQQVCT  Gross/Near total resection
# PT_ZZWYKZZ8                Not Reported
#
#                                             HISTOLOGY  MUTATION_COUNT  \
# patientId
# PT_00G007DM  Embryonal tumor with multilayer rosettes             2.0
# PT_00G007DM  Embryonal tumor with multilayer rosettes             4.0
# PT_01MZ62KG  Embryonal tumor with multilayer rosettes            11.0
# PT_02J5CWN5              Low-grade glioma astrocytoma             7.0
# PT_02J5CWN5              Low-grade glioma astrocytoma             1.0
# ...                                               ...             ...
# PT_ZZRBX5JT                                Ependymoma            17.0
# PT_ZZRBX5JT                                Ependymoma             5.0
# PT_ZZRBX5JT                                Ependymoma             2.0
# PT_ZZTQQVCT              Low-grade glioma astrocytoma             1.0
# PT_ZZWYKZZ8                                Ependymoma             NaN
#
#                                  PATHOLOGY_FREE_TEXT_DIAGNOSIS   SAMPLE_TYPE  \
# patientId
# PT_00G007DM                                   ependymoblastoma  Solid Tissue
# PT_00G007DM  embryonal tumor with abundant neuropil and tru...  Solid Tissue
# PT_01MZ62KG                                      pineoblastoma  Solid Tissue
# PT_02J5CWN5                                   low-grade glioma  Solid Tissue
# PT_02J5CWN5                                   low-grade glioma  Solid Tissue
# ...                                                        ...           ...
# PT_ZZRBX5JT                                         ependymoma  Solid Tissue
# PT_ZZRBX5JT                                         ependymoma  Solid Tissue
# PT_ZZRBX5JT                                         ependymoma  Solid Tissue
# PT_ZZTQQVCT                                   low-grade glioma  Solid Tissue
# PT_ZZWYKZZ8                                         ependymoma  Solid Tissue
#
#                          SPECIMEN_ID  TUMOR_FRACTION  TUMOR_PLOIDY  \
# patientId
# PT_00G007DM  BS_AQMKA8NC;BS_FEPRNEXX        0.613054           4.0
# PT_00G007DM  BS_K07KNTFY;BS_QWNBZ9RJ        0.328185           4.0
# PT_01MZ62KG  BS_TE8QFF7T;BS_P39SQPTS             NaN           NaN
# PT_02J5CWN5  BS_2VB8649B;BS_M8WP5T16        1.000000           2.0
# PT_02J5CWN5  BS_5TT6TT4K;BS_1RXZ3BP7             NaN           NaN
# ...                              ...             ...           ...
# PT_ZZRBX5JT  BS_JE1DF581;BS_HZ707C55             NaN           NaN
# PT_ZZRBX5JT  BS_9N3B3HZB;BS_YE1MAQYJ        0.503286           2.0
# PT_ZZRBX5JT  BS_AGD2ATY1;BS_PJPGVD62        0.256150           2.0
# PT_ZZTQQVCT  BS_78TQS4Y3;BS_Y7F9E2E9        1.000000           2.0
# PT_ZZWYKZZ8  BS_2E81A3FT;BS_7B89YR6K        1.000000           2.0
#
#                                  TUMOR_TISSUE_SITE   TUMOR_TYPE
# patientId
# PT_00G007DM             Cerebellum/Posterior Fossa   recurrence
# PT_00G007DM             Cerebellum/Posterior Fossa      primary
# PT_01MZ62KG             Cerebellum/Posterior Fossa  progression
# PT_02J5CWN5     Suprasellar/Hypothalamic/Pituitary      primary
# PT_02J5CWN5     Suprasellar/Hypothalamic/Pituitary  progression
# ...                                            ...          ...
# PT_ZZRBX5JT             Cerebellum/Posterior Fossa   recurrence
# PT_ZZRBX5JT         Spinal Cord- Lumbar/Thecal Sac   recurrence
# PT_ZZRBX5JT                             Ventricles      primary
# PT_ZZTQQVCT             Cerebellum/Posterior Fossa      primary
# PT_ZZWYKZZ8  Cerebellum/Posterior Fossa;Ventricles  progression
#
# [1121 rows x 15 columns]

# %%
def get_cbtn_cell_lines():
    df = import_pedcbioportal_metadata()
    df = df[df.SAMPLE_TYPE == "Derived Cell Line"]
    return df.SPECIMEN_ID.str.cat(sep=';').split(';')

#duplicated_cbtn_samples = ["BS_DRVEFVQ5","BS_169P1QCA","BS_QG6V29H7",
#                           "BS_6GV08HTE","BS_B4PPG3X5","BS_2X60Q1ET","BS_S791VC80","BS_STNH7YSX","BS_3Z40EZHD","BS_ZR75EKKX",
#                           "BS_KQPCYZ2K","BS_Z64NEPNE","BS_KQRAHH6Y","BS_KH3859M5","BS_HJ7HYZ7N","BS_AH3RVK53",
#                           "BS_5S8VXASX","BS_JEZBA2EW","BS_XNYQS1WG","BS_P99S85CY",
#                           "BS_M5FM63EB","BS_M0B42FPR","BS_TX2WGF8K","BS_RENPFFNK","BS_R6CKWZW6",
#                           "BS_ZSH09N84","BS_6TMPZKSZ","BS_B91XGSA5","BS_XQF18WZP","BS_0TCRV9AC",
#                           "BS_2J4FG4HV",
#                           "BS_EE73VE7V","BS_5968GBGT","BS_BQ81D2BP","BS_3VKW5988", # duplicate samples from PT_KTRJ8TFY autopsy
#                           "BS_AK9BV52G","BS_X5VN0FW0","BS_D6STCMQS","BS_22VCR7DF","BS_1Q524P3B" # duplicate samples from PT_KZ56XHJT autopsy
#                          ]
#nontumor_samples = ["BS_MCM78YPC","BS_886M7JMG","BS_TPX7YY57"] # Epilepsy, Arteriovenous malformation, and Reactive connective tissue respectively
# Out:
# ['BS_CZRA594T',
#  'BS_59ZJWJTF',
#  'BS_ERAWW3H7',
#  'BS_QYPHA40N',
#  'BS_PKZ1HWNB',
#  'BS_M8EA6R2A',
#  'BS_FJEZ3ASV',
#  'BS_8ZD6J47V',
#  'BS_68TZMZH1',
#  'BS_0RQ4P069',
#  'BS_AFBPM6CN',
#  'BS_PNYN0AYD',
#  'BS_TX8C5VAJ',
#  'BS_GXTFW99H',
#  'BS_QWM9BPDY',
#  'BS_BWBDH9GM',
#  'BS_HM5GFJN8',
#  'BS_2A162JH9',
#  'BS_RXP2ZRQT',
#  'BS_40MP5BWR',
#  'BS_QZRP3NSG',
#  'BS_DVDT4VXQ',
#  'BS_6JBE0947',
#  'BS_YZD4SSMA',
#  'BS_M659G06J',
#  'BS_5GNQC2FF',
#  'BS_VXDGXQKZ',
#  'BS_ERFMPQN3',
#  'BS_PGK832G2',
#  'BS_4DQAQFQH',
#  'BS_XMP9XNR9',
#  'BS_P9JP6JFA',
#  'BS_JGKRN7NA',
#  'BS_MX23ZY0Y',
#  'BS_853PNV7P',
#  'BS_DRY58DTF',
#  'BS_TF5TTEXH',
#  'BS_E60JZ9Z3']

# %%
def propagate(df,dest,source,rename=False):
    '''
    Replace NA values in dest with those in source, then drop source and rename dest
    '''
    df[dest].fillna(df[source], inplace=True)
    df.drop(source, inplace=True, axis=1)
    if rename:
        df = df.rename(columns={dest:rename})
    return df
def consensus(df,dest,source,rename=False):
    '''
    Check that values in dest and source agree, if not then set to NA. Drop source and rename dest.
    '''
    df.loc[df[dest] != df[source], dest] = None
    df.drop(source, inplace=True, axis=1)
    if rename:
        df = df.rename(columns={dest:rename})
    return df

# %%
## Integrate all CBTN data available
def generate_cbtn_biosample_table(verbose=0):
    '''
    Generate a metadata table of cbtn biosamples.
    verbose:
        0: most useful metadata only. These are included in the Supplmentary Table.
        1: includes some extra columns. Useful for generating the patient metadata table.
        2: includes lots of extra columns
    '''
    df = pd.DataFrame(index=get_pedpancan_biosamples_from_AC())
    cavatica_data = import_cbtn_biosample_metadata()
    df = pd.merge(left=df,how='inner',right=cavatica_data,left_index=True,right_index=True)
    opentarget_data = import_opentarget_histologies_files()
    df = pd.merge(left=df,how='left',right=opentarget_data,left_index=True,right_index=True,suffixes=(None,"_y"))

    # For CAVATICA annotations which are missing, propagate those from opentarget.
    df = propagate(df,"primary_site","primary_site_y")
    df = propagate(df,"age_at_diagnosis","age_at_diagnosis_days")
    df = propagate(df,"Tumor Descriptor","tumor_descriptor")
    df = consensus(df,"gender","reported_gender","sex")
    
    # Rename columns
    df.index.name = "biosample_id"
    df = df.rename(columns={
        'Kids First Participant ID':'patient_id',
        'Tumor Descriptor':'tumor_history',
        'case_id':'external_patient_id',
        'sample_id':'external_sample_id',
    })

    # drop columns
    if verbose < 2:
        df = df.drop(["race","ethnicity","external_patient_id","WGS_UUID","Kids First Biospecimen ID Normal",
                      "sample_id_y","composition","Kids_First_Participant_ID","experimental_strategy","sample_type",
                      "germline_sex_estimate","race_y","ethnicity_y","molecular_subtype_methyl","cohort_participant_id","Notes"
                     ],axis=1)  
    if verbose < 1:
        df = df.drop(["primary_site","pathology_diagnosis","OS_days","OS_status","EFS_days","age_last_update_days","aliquot_id",
                      "cancer_predispositions","CNS_region","age_at_chemo_start","age_at_radiation_start","cancer_group",
                      "age_at_event_days","clinical_status_at_event"
                     ],axis=1)
    # Drop nontumor samples
    #df = df.drop(nontumor_samples)
    
    # Drop cell lines
    #df = df[~df.index.isin(get_cbtn_cell_lines())]
    
    # Mark duplicates
    #df['in_deduplicated_sample_cohort'] = True
    #df.loc[duplicated_cbtn_samples,'in_deduplicated_sample_cohort'] = False
    return df

## SJ data
# duplicated_sj_samples are biosamples where we suspect that the same tumor was sequenced twice at the same timepoint. 
# These are flagged and removed arbitrarily.
#duplicated_sj_samples = ['SJST030043_D1','SJST030131_D1','SJMEL001003_D2','SJOS001115_D1','SJMB009_E',
#                         'SJDSRCT030041_D3','SJBT030081_D2','SJWLM030180_D2','SJHGG017_D','SJEWS030228_D2',
#                         'SJST030383_D1','SJLGG017_D','SJLGG030611_D2','SJOS030876_D2','SJOS001101_M1','SJHM030702_D2']
# what to do with SJOS001101_M1?
CBTN_df = generate_cbtn_biosample_table()
CBTN_df.head()
# Out:
# /var/folders/vv/261hv1sn1h36hvx1wc1cv9w40000gp/T/ipykernel_85943/2192161946.py:6: DtypeWarning: Columns (1,21,24,25,26,27,33,36,37,41,43,45,47,48,49,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path,sep='\t',index_col=0)
# Warning: The column 'harmonized_diagnosis' for sample 7316-1101 differs between CAVATICA and opentarget annotations.
# Warning: The column 'harmonized_diagnosis' for sample 7316-2935 differs between CAVATICA and opentarget annotations.
# Warning: The column 'tumor_descriptor' for sample 7316-3217 differs between CAVATICA and opentarget annotations.
# Warning: The column 'primary_site' for sample 7316-3229 differs between CAVATICA and opentarget annotations.
# Warning: The column 'age_at_diagnosis_days' for sample 7316-323 differs between CAVATICA and opentarget annotations.
# Warning: The column 'primary_site' for sample 7316-3230 differs between CAVATICA and opentarget annotations.
# Warning: The column 'CNS_region' for sample 7316-3230 differs between CAVATICA and opentarget annotations.
# Warning: The column 'primary_site' for sample 7316-3231 differs between CAVATICA and opentarget annotations.
# Warning: The column 'harmonized_diagnosis' for sample 7316-3295 differs between CAVATICA and opentarget annotations.
# Warning: The column 'harmonized_diagnosis' for sample 7316-3632 differs between CAVATICA and opentarget annotations.
# Warning: The column 'harmonized_diagnosis' for sample 7316-4062 differs between CAVATICA and opentarget annotations.
# Warning: The column 'harmonized_diagnosis' for sample 7316-921 differs between CAVATICA and opentarget annotations.
# 53 KF biospecimens missing from the opentarget histologies table...
# found 41 matching external sample IDs, adding to table...
#                  sex   patient_id                             disease_type  \
# biosample_id
# BS_85Y70BHE   Female  PT_124TTG01                                  Adenoma
# BS_A9S5HT6P   Female  PT_9XAA8PF6                                  Adenoma
# BS_1EQGGHHQ   Female  PT_XP8AM1CH                                  Adenoma
# BS_BR1X3R68   Female  PT_ZN1F7RMP                                  Adenoma
# BS_JDMM2XG4     Male  PT_32J909WM  Atypical Teratoid Rhabdoid Tumor (ATRT)
#
#              external_sample_id tumor_history  age_at_diagnosis    cohort  \
# biosample_id
# BS_85Y70BHE           7316-1960     Diagnosis              5916  PBTA-X00
# BS_A9S5HT6P           7316-1069     Diagnosis              4964  PBTA-X00
# BS_1EQGGHHQ           7316-1096     Diagnosis              5713  PBTA-X00
# BS_BR1X3R68           7316-1080     Diagnosis              7032  PBTA-X00
# BS_JDMM2XG4           7316-2688     Diagnosis               860  PBTA-X00
#
#                extent_of_tumor_resection dkfz_v11_methylation_subclass  \
# biosample_id
# BS_85Y70BHE   Gross/Near total resection              PITAD, STH DNS A
# BS_A9S5HT6P   Gross/Near total resection                           NaN
# BS_1EQGGHHQ   Gross/Near total resection                   PITAD, ACTH
# BS_BR1X3R68            Partial resection                    PITAD, TSH
# BS_JDMM2XG4   Gross/Near total resection                     ATRT, TYR
#
#               dkfz_v11_methylation_subclass_score  \
# biosample_id
# BS_85Y70BHE                                 0.857
# BS_A9S5HT6P                                   NaN
# BS_1EQGGHHQ                                 1.000
# BS_BR1X3R68                                 0.981
# BS_JDMM2XG4                                 0.594
#
#              dkfz_v12_methylation_subclass  \
# biosample_id
# BS_85Y70BHE               PITAD_STH_DENSE1
# BS_A9S5HT6P                            NaN
# BS_1EQGGHHQ                     PITAD_ACTH
# BS_BR1X3R68                      PITAD_TSH
# BS_JDMM2XG4                       ATRT_SHH
#
#               dkfz_v12_methylation_subclass_score       molecular_subtype  \
# biosample_id
# BS_85Y70BHE                              0.967892                     NaN
# BS_A9S5HT6P                                   NaN                     NaN
# BS_1EQGGHHQ                              0.999998                     NaN
# BS_BR1X3R68                              0.996686                     NaN
# BS_JDMM2XG4                              0.105467  ATRT, To be classified
#
#                                  harmonized_diagnosis  broad_histology  \
# biosample_id
# BS_85Y70BHE                                   Adenoma     Benign tumor
# BS_A9S5HT6P                                   Adenoma     Benign tumor
# BS_1EQGGHHQ                                   Adenoma     Benign tumor
# BS_BR1X3R68                                   Adenoma     Benign tumor
# BS_JDMM2XG4   Atypical Teratoid Rhabdoid Tumor (ATRT)  Embryonal tumor
#
#              short_histology
# biosample_id
# BS_85Y70BHE          Adenoma
# BS_A9S5HT6P          Adenoma
# BS_1EQGGHHQ          Adenoma
# BS_BR1X3R68          Adenoma
# BS_JDMM2XG4             ATRT

# %%
def import_sj_sample_info(path="SAMPLE_INFO_2022-03-02.tsv"):
    path = pathlib.Path(path)
    df = pd.read_csv(path,sep='\t',index_col="sample_name")
    return df
def clean_sj_biosample_metadata(df):
    '''
    Clean known errors in the sj metadata, and unify ontologies, units etc.
    '''
    df = df.replace({
        'attr_age_at_diagnosis':{
            "Not Available": None
        },
        'attr_sex':{
            "Not Available":None
        }
    })
    
    # Convert age from years to days
    df['attr_age_at_diagnosis'] = (pd.to_numeric(df['attr_age_at_diagnosis'],errors='coerce')*365.25).round()
    
    return df
def generate_sj_biosample_table(verbose=0):
    '''
    Notes:
    sj_diseases != attr_oncotree_disease_code = sj_associated_diagnoses_disease_code
    attr_diagnosis != sj_long_disease_name != sj_associated_diagnoses
    '''
    df = pd.DataFrame(index=get_pedpancan_biosamples_from_AC())
    columns = ['subject_name','sample_type','attr_age_at_diagnosis','attr_sex','sj_long_disease_name','sj_diseases','attr_oncotree_disease_code','sj_dataset_accessions']
    add = import_sj_sample_info()
    add = clean_sj_biosample_metadata(add)
    add = add[(add.sequencing_type == 'WGS') & (add.file_type == 'BAM') & add.file_path.str.endswith('.bam')]
#    add = add.sort_values(columns)
#    add = add.loc[~add.index.duplicated()]
    df = pd.merge(left=df,how='inner',right=add, left_index=True, right_index=True)
    
    # Rename columns
    df.index.name = "biosample_id"
    df = df.rename(columns={
        'subject_name':'patient_id',
        'sample_type':'tumor_history',
        'attr_sex':'sex',
        'sj_dataset_accessions':'cohort',
        'attr_age_at_diagnosis':'age_at_diagnosis',
    })
    # drop columns
    if verbose < 2:
        df = df.drop(["file_path","file_id","sequencing_type","file_type","description","sj_embargo_date","attr_ethnicity","attr_race",
                      "sj_genome_build","sj_pipeline_name","sj_pipeline_version","attr_library_selection_protocol","attr_read_length",
                      "attr_sequencing_platform","attr_read_type","attr_tissue_preservative","attr_inferred_strandedness",
                      "attr_lab_strandedness","attr_germline_sample"
        ],axis=1)
    if verbose < 1:
        df = df.drop(["sj_pmid_accessions","sj_publication_titles","sj_pub_accessions","sj_datasets","sj_ega_accessions","attr_diagnosis",
                      "attr_diagnosis_group","attr_oncotree_disease_code","attr_subtype_biomarkers","sj_associated_diagnoses",
                      "sj_associated_diagnoses_disease_code"
        ],axis=1)
    
    # Mark duplicates
    #df['in_deduplicated_sample_cohort'] = True
    #df.loc[duplicated_sj_samples,'in_deduplicated_sample_cohort'] = False
    return df

SJ_df = import_sj_sample_info()
SJ_df = clean_sj_biosample_metadata(SJ_df)
SJ_df = generate_sj_biosample_table()
SJ_df.head()
# Out:
#              patient_id tumor_history      sj_long_disease_name       cohort  \
# biosample_id
# SJACT001_D     SJ006401     Diagnosis  Adrenocortical Carcinoma  SJC-DS-1001
# SJACT002_D     SJ006402     Diagnosis  Adrenocortical Carcinoma  SJC-DS-1001
# SJACT003_D     SJ006403     Diagnosis  Adrenocortical Carcinoma  SJC-DS-1001
# SJACT004_D     SJ006404     Diagnosis  Adrenocortical Carcinoma  SJC-DS-1001
# SJACT005_D     SJ006405     Diagnosis  Adrenocortical Carcinoma  SJC-DS-1001
#
#              sj_diseases  age_at_diagnosis     sex
# biosample_id
# SJACT001_D           ACC            1088.0  Female
# SJACT002_D           ACC             961.0  Female
# SJACT003_D           ACC             475.0  Female
# SJACT004_D           ACC            1819.0  Female
# SJACT005_D           ACC            5621.0  Female

# %%
## Generate the unified biosample table

# print(mapping_dict)
# Function to create the cancer_subtype column based on priority
priority_columns = ['molecular_subtype','dkfz_v12_methylation_subclass',
                    'dkfz_v11_methylation_subclass', 'harmonized_diagnosis', 'disease_type']  # Add other columns as needed
def get_subtype(row):
    for col in priority_columns:
        if col in ['dkfz_v12_methylation_subclass', 'dkfz_v11_methylation_subclass'] and pd.notnull(row[col]) and row[f"{col}_score"] > 0.9:
            return row[col]
        elif col not in ['dkfz_v12_methylation_subclass', 'dkfz_v11_methylation_subclass'] and pd.notnull(row[col]):
            return row[col]
    return None
def unify_tumor_diagnoses_CBTN(df):
    # Apply the function to create the cancer_subtype column
    mapping = pd.read_excel("CBTN_mapping.xlsx", 'filtered_mapping')
    mapping_dict = dict(zip(mapping['Classification'], mapping['Owen']))
    df['cancer_subtype'] = df.apply(get_subtype, axis=1)  
    df['cancer_subtype'] = df['cancer_subtype'].map(mapping_dict)
    df = df.drop(["disease_type","dkfz_v11_methylation_subclass","dkfz_v11_methylation_subclass_score",
                  "dkfz_v12_methylation_subclass","dkfz_v12_methylation_subclass_score","molecular_subtype","harmonized_diagnosis",
                  "broad_histology","short_histology"
                 ],axis=1)
    return df
def unify_tumor_diagnoses_SJ(df):
    df = df.rename(columns = {"sj_diseases":"cancer_subtype"})
    df = df.drop("sj_long_disease_name", axis = 1)
    return df

# %%
def generate_biosample_table(CBTN_df, SJ_df):
    CBTN_df = unify_tumor_diagnoses_CBTN(CBTN_df)
    SJ_df = unify_tumor_diagnoses_SJ(SJ_df)
    df = pd.concat([CBTN_df,SJ_df])
    return df

df = generate_biosample_table(CBTN_df, SJ_df)
df.head()
# Out:
#                  sex   patient_id external_sample_id tumor_history  \
# biosample_id
# BS_85Y70BHE   Female  PT_124TTG01          7316-1960     Diagnosis
# BS_A9S5HT6P   Female  PT_9XAA8PF6          7316-1069     Diagnosis
# BS_1EQGGHHQ   Female  PT_XP8AM1CH          7316-1096     Diagnosis
# BS_BR1X3R68   Female  PT_ZN1F7RMP          7316-1080     Diagnosis
# BS_JDMM2XG4     Male  PT_32J909WM          7316-2688     Diagnosis
#
#               age_at_diagnosis    cohort   extent_of_tumor_resection  \
# biosample_id
# BS_85Y70BHE             5916.0  PBTA-X00  Gross/Near total resection
# BS_A9S5HT6P             4964.0  PBTA-X00  Gross/Near total resection
# BS_1EQGGHHQ             5713.0  PBTA-X00  Gross/Near total resection
# BS_BR1X3R68             7032.0  PBTA-X00           Partial resection
# BS_JDMM2XG4              860.0  PBTA-X00  Gross/Near total resection
#
#              cancer_subtype
# biosample_id
# BS_85Y70BHE            BENG
# BS_A9S5HT6P            BENG
# BS_1EQGGHHQ            BENG
# BS_BR1X3R68            BENG
# BS_JDMM2XG4            ATRT

# %%
## Imports for Sunita's data
def import_sunita_classifications(path='../data/combinedamplicons.xlsx'):
    df = pd.read_excel(path)
    df = df[["sample_ID","cancer_type"]]
    df = df.drop_duplicates()
    df = df.set_index("sample_ID")
    return df
