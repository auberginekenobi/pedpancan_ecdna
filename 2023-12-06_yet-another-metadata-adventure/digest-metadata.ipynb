# %%
import pandas as pd
import pathlib
import os

pd.set_option('display.max_columns', None)

# %%
def import_openpbta_biosample_metadata(path="../2023-11-27_cavatica-api/out/openpbta-biosample-metadata.tsv"):
    '''
    NB use HISTOLOGY for diagnosis
    Index(['patientId', 'CANCER_TYPE', 'CANCER_TYPE_DETAILED', 'CNS_REGION',
       'EXPERIMENTAL_STRATEGY', 'EXTENT_OF_TUMOR_RESECTION', 'HISTOLOGY',
       'MUTATION_COUNT', 'PATHOLOGY_FREE_TEXT_DIAGNOSIS', 'SAMPLE_TYPE',
       'SPECIMEN_ID', 'TUMOR_FRACTION', 'TUMOR_PLOIDY', 'TUMOR_TISSUE_SITE',
       'TUMOR_TYPE']
    '''
    path = pathlib.Path(path)
    df = pd.read_csv(path, sep='\t',index_col=1)
    return df

def clean_opentarget_histologies_biosamples(df):
    '''
    Add missing BS_ biospecimen IDs based on matching sample IDs
    '''
    x00 = pd.concat([import_x00_biosample_metadata(),import_pnoc_biosample_metadata()])
    missing_bs = (x00[~x00.index.isin(df.index)]["sample_id"]).sort_values()
    print(f"{len(missing_bs)} KF biospecimens missing from the opentarget histologies table...")
    missing_bs = missing_bs[missing_bs.isin(df.sample_id)]
    print(f"found {len(missing_bs)} matching external sample IDs, adding to table...")
    newdf = []
    for biospecimen, sample in missing_bs.items():
        newentry=df[df.sample_id==sample].iloc[0]
        newentry.name = biospecimen
        newdf.append(newentry)
    newdf = pd.DataFrame(newdf)
    df = pd.concat([df,newdf])
    return df
    
def import_opentarget_histologies_biosamples(path='../data/local/opentarget/histologies-wgs-cohort.xlsx'):
    path = pathlib.Path(path)
    df = pd.read_excel(path,index_col='sample_id')
    df["Kids_First_Biospecimen_ID"]=df["Kids_First_Biospecimen_ID"].map(lambda x:x.split(';'))
    df = df.explode("Kids_First_Biospecimen_ID")
    df['sample_id'] = df.index
    df = df.set_index("Kids_First_Biospecimen_ID")
    df = clean_opentarget_histologies_biosamples(df)
    return df
def import_opentarget_histologies_files(path='/Users/ochapman/Library/CloudStorage/OneDrive-SanfordBurnhamPrebysMedicalDiscoveryInstitute/projects/2023-pedpancan/data/metadata/histologies.tsv'):
    path = pathlib.Path(path)
    df = pd.read_csv(path,sep='\t')
    return df

def import_sunita_cbtn_master_table(sheet='1a Patients',path='/Users/ochapman/Library/CloudStorage/OneDrive-SanfordBurnhamPrebysMedicalDiscoveryInstitute/projects/2023-pedpancan/data/latest/PedPanCancer_CBTN_MasterAnalysis_Copy.xlsx'):
    """
    Patient_ID	Source	Database	ecDNA	amplicon_type	CancerAbbr	Cancer_Type_Abbrev	Age	Cancer_Type	Cancer_Type_Detailed	CNS_region	Ethnicity	Fraction Genome Altered	Mutation Count	Oncotree_Code	OS_Months	OS_Months_5yrCensor	OS_Status	OS_Status_5yrCensor	PFS_Months	Race	Number of Samples Per Patient	Sample_Type	Sex	Tumor_Tissue_Site	Tumor_Type	Notes	EGFR_SV	ec_EGFR	EGFR_Status	EGFR_SV_Status	EGFR_RNA_Expression	ATRX_RNA_Expression_Zscore	BRAF_RNA_Expression_Zscore	GACAT3_RNA_Expression_Zscore	EGFR_RNA_Expression_Zscore	H3F3A_RNA_Expression_Zscore	KIAA1549_RNA_Expression_Zscore	MYC_RNA_Expression_Zscore	MYCN_RNA_Expression_Zscore	PLAG1_RNA_Expression_Zscore	PVT1_RNA_Expression_Zscore	TARSL2_RNA_Expression_Zscore	TP53_RNA_Expression_Zscore	WFS1_RNA_Expression_Zscore
    """
    path = pathlib.Path(path)
    index = None
    if sheet == '1a Patients':
        index = "Patient_ID"
    elif sheet == '1b Samples':
        index = "Specimen_ID"
    df = pd.read_excel(path,sheet_name=sheet,index_col=index)
    return df
def import_sunita_sj_master_table(path="/Users/ochapman/Library/CloudStorage/OneDrive-SanfordBurnhamPrebysMedicalDiscoveryInstitute/projects/2023-pedpancan/data/latest/SJ_SurvivalMaster.xlsx"):
    path=pathlib.Path(path)
    df = pd.read_excel(path,index_col=0)
    return df
def clean_sunita_survival_table(df):
    df['Overall Survival in Months'] = pd.to_numeric(df['Overall Survival in Months'].astype(str).str.replace('m', '', regex=False), errors='coerce')
    return df
def import_sunita_survival_table(path="../data/combinedsurv.xlsx"):
    path = pathlib.Path(path)
    df = pd.read_excel(path,index_col=0)
    df = clean_sunita_survival_table(df)
    return df
def import_sunita_amplicons_table(path="../data/combinedamplicons.xlsx"):
    path = pathlib.Path(path)
    df = pd.read_excel(path)
    return df
def import_sj_sample_info(path="/Users/ochapman/projects/pedpancan_ecdna/2022-02-23_sj_samples/SAMPLE_INFO_2022-03-02.tsv"):
    path = pathlib.Path(path)
    df = pd.read_csv(path,sep='\t',index_col="sample_name")
    return df
def get_pedpancan_biosamples_from_AC(include_x01=False,path='../data/local/AmpliconClassifier/pedpancan_summary_map.txt'):
    path = pathlib.Path(path)
    df = pd.read_csv(path, sep='\t', header=None, index_col=0, names = ["biosample","file"])
    if not include_x01:
        df['firstletter']=df.index.map(lambda x: x[0])
        df = df[df.firstletter != 'P']
    return df.index

# %%
#df = import_x01_biosample_metadata()
#df = import_openpbta_biosample_metadata()
#df = get_pedpancan_biosamples_from_AC()
#df = import_sunita_patient_table()
#df = import_sunita_survival_table()
#df = import_sunita_amplicons_table()
#df = import_sunita_sj_master_table()
#df = import_sj_sample_info("/Users/ochapman/projects/pedpancan_ecdna/2022-02-23_sj_samples/SAMPLE_INFO_batch_2022-03-03.txt")
#(df.loc["SJAML001417_D1","Date of Primary Dx"]-df.loc["SJAML001417_D1","Date of Death"]).days
#df = get_pedpancan_biosamples_from_AC()
#CBTN_samples = set(df[df.map(lambda x: x.startswith('B'))])
df = import_pnoc_biosample_metadata()
df
# Out:
#                            gender              race               ethnicity
# Kids First Biospecimen ID
# BS_8SYN7GXG                  Male             White  Not Hispanic or Latino  \
# BS_DRVEFVQ5                  Male  Reported Unknown        Reported Unknown
# BS_Y96RP1HJ                  Male  Reported Unknown        Reported Unknown
# BS_7GKF6M85                Female             Asian  Not Hispanic or Latino
# BS_169P1QCA                  Male             White  Not Hispanic or Latino
# ...                           ...               ...                     ...
# BS_VXDGXQKZ                Female  Reported Unknown        Reported Unknown
# BS_38CD519Z                  Male             Asian      Hispanic or Latino
# BS_4DQAQFQH                Female  Reported Unknown      Hispanic or Latino
# BS_TQ0J7WJQ                Female  Reported Unknown      Hispanic or Latino
# BS_5Z0GA574                Female             White  Not Hispanic or Latino
#
#                           Kids First Participant ID
# Kids First Biospecimen ID
# BS_8SYN7GXG                             PT_0MXPTTM3  \
# BS_DRVEFVQ5                             PT_1AAYYGGY
# BS_Y96RP1HJ                             PT_1AAYYGGY
# BS_7GKF6M85                             PT_1E3E6GMF
# BS_169P1QCA                             PT_1YQH5NSH
# ...                                             ...
# BS_VXDGXQKZ                             PT_VPEMAQBN
# BS_38CD519Z                             PT_W5GP3F6B
# BS_4DQAQFQH                             PT_WGVEF96B
# BS_TQ0J7WJQ                             PT_WGVEF96B
# BS_5Z0GA574                             PT_Y74CVASJ
#
#                                                                 disease_type
# Kids First Biospecimen ID
# BS_8SYN7GXG                                           Anaplastic Astrocytoma  \
# BS_DRVEFVQ5                                           Anaplastic Astrocytoma
# BS_Y96RP1HJ                                           Anaplastic Astrocytoma
# BS_7GKF6M85                                              Diffuse Astrocytoma
# BS_169P1QCA                Diffuse midline glioma; H3K27M mutant; WHO gra...
# ...                                                                      ...
# BS_VXDGXQKZ                                           Anaplastic Astrocytoma
# BS_38CD519Z                Diffuse midline glioma; H3K27M mutant; WHO gra...
# BS_4DQAQFQH                                              Diffuse Astrocytoma
# BS_TQ0J7WJQ                                              Diffuse Astrocytoma
# BS_5Z0GA574                                                     Glioblastoma
#
#                            sample_id Tumor Descriptor primary_site
# Kids First Biospecimen ID
# BS_8SYN7GXG                7316-3220        Diagnosis   Brain Stem  \
# BS_DRVEFVQ5                7316-4996        Diagnosis   Brain Stem
# BS_Y96RP1HJ                7316-4996        Diagnosis   Brain Stem
# BS_7GKF6M85                7316-3224        Diagnosis   Brain Stem
# BS_169P1QCA                7316-5922        Diagnosis   Brain Stem
# ...                              ...              ...          ...
# BS_VXDGXQKZ                7316-3235        Diagnosis   Brain Stem
# BS_38CD519Z                7316-5003        Diagnosis   Brain Stem
# BS_4DQAQFQH                7316-4446        Diagnosis   Brain Stem
# BS_TQ0J7WJQ                7316-3219        Diagnosis   Brain Stem
# BS_5Z0GA574                7316-5002        Diagnosis   Brain Stem
#
#                            age_at_diagnosis   case_id
# Kids First Biospecimen ID
# BS_8SYN7GXG                            9425  C3080535  \
# BS_DRVEFVQ5                            4608  C3079920
# BS_Y96RP1HJ                            4608  C3079920
# BS_7GKF6M85                            2211  C3081150
# BS_169P1QCA                            2520  C3093819
# ...                                     ...       ...
# BS_VXDGXQKZ                            1709  C3078444
# BS_38CD519Z                            2459  C3092712
# BS_4DQAQFQH                            2853  C3080043
# BS_TQ0J7WJQ                            2853  C3080043
# BS_5Z0GA574                            1717  C3081519
#
#                                                        WGS_UUID
# Kids First Biospecimen ID
# BS_8SYN7GXG                3526c1ab-a793-4c5f-9576-d922835dbd78
# BS_DRVEFVQ5                d182b330-17aa-47de-9c3a-5fee37a4ee33
# BS_Y96RP1HJ                e3629477-53cc-40c6-a4f6-72ecc70a4451
# BS_7GKF6M85                2865b67b-1458-492e-a39e-57900f34da9f
# BS_169P1QCA                64b37304-0567-4f2c-9790-b3cce218955c
# ...                                                         ...
# BS_VXDGXQKZ                7ad281cf-82c0-46b9-9a23-8348d623ba77
# BS_38CD519Z                80fd23ab-de59-45da-80f6-49af162fe982
# BS_4DQAQFQH                3d9ec140-cf1f-48e0-b4bd-d9ae775b29b0
# BS_TQ0J7WJQ                c2e040bd-64b7-4928-8428-1da909cb2873
# BS_5Z0GA574                a7eaf642-8f59-4b80-a1c1-709afc030e16
#
# [72 rows x 11 columns]

# %%
# Which data are useful?
# 993 total CBTN biosamples
biosamples = set(get_pedpancan_biosamples_from_AC())
print(len(biosamples))
# x00: 921 biosamples in dataset
x00 = set(import_x00_biosample_metadata().index)
print(len(biosamples & x00))
# pnoc: 72 biosamples in dataset
x00 = set(import_pnoc_biosample_metadata().index)
print(len(biosamples & pnoc))
# opentarget: 980 biosamples in dataset
ot = set(import_opentarget_histologies_biosamples().index)
print(len(biosamples & ot))

# sj_master: 717 biosamples in dataset
# x00, pnoc mutually exclusive
# SAMPLE_INFO_batch_2022-03-03

sjinfo="/Users/ochapman/projects/pedpancan_ecdna/2022-02-23_sj_samples/SAMPLE_INFO_batch_2022-03-03.txt" # 0 overlap
sjinfo="/Users/ochapman/projects/pedpancan_ecdna/2022-02-23_sj_samples/SAMPLE_INFO_2022-03-02.tsv" # 717 overlap
sjinfo="/Users/ochapman/projects/pedpancan_ecdna/2022-02-23_sj_samples/SAMPLE_INFO PedPanCancer ecDNA.txt" # 717 overlap but the metadata is less complete
sjinfo="/Users/ochapman/projects/pedpancan_ecdna/2022-02-23_sj_samples/SAMPLE_INFO PedPanCan_clinical.txt" # 256 overlap
sj = set(import_sj_sample_info(sjinfo).index)
print(len(ot & sj))

print((x00 - ot))
# Out:
# 1710
# 921
# 72
# 37 KF biospecimens missing from the opentarget histologies table...
# found 24 matching external sample IDs, adding to table...
# 980
# 0
# {'BS_4DQAQFQH', 'BS_M0B42FPR', 'BS_QZRP3NSG', 'BS_M5FM63EB', 'BS_JEZBA2EW', 'BS_6JBE0947', 'BS_KQPCYZ2K', 'BS_VXDGXQKZ', 'BS_AH3RVK53'}

# %%
def _unify_diagnoses(df):
    pass

def generate_cbtn_biosample_table():
    '''
    '''
    df = pd.DataFrame(index=get_pedpancan_biosamples_from_AC())
    cavatica_data = pd.concat([import_x00_biosample_metadata(),import_pnoc_biosample_metadata()])
    cavatica_data = cavatica_data[['gender','Kids First Participant ID','disease_type','sample_id','Tumor Descriptor','primary_site','age_at_diagnosis']]
    df = pd.merge(left=df,how='inner',right=cavatica_data,left_index=True,right_index=True)
    opentarget_data = import_opentarget_histologies_biosamples()
    #
    opentarget_data = opentarget_data.drop(["sample_id","composition"],axis=1)
    #opentarget_data = opentarget_data[[]]
    # don't include race, ethnicity
    df = pd.merge(left=df,how='left',right=opentarget_data,left_index=True,right_index=True)
    
    df
    return df

df = generate_cbtn_biosample_table()
df[df.disease_type != df.pathology_diagnosis]
# Out:
# 37 KF biospecimens missing from the opentarget histologies table...
# found 24 matching external sample IDs, adding to table...
#              gender Kids First Participant ID
# BS_EBCJ4Y49    Male               PT_W6CW60K9  \
# BS_C3KDA5ZC    Male               PT_YQWG98Z5
# BS_HNE6BPMH    Male               PT_V5ASTHRH
# BS_F8K4VQMF    Male               PT_J5NSRW1Y
# BS_1YTHM07J  Female               PT_279D9QZ8
# ...             ...                       ...
# BS_AH3RVK53  Female               PT_EN2RN5Y1
# BS_JEZBA2EW  Female               PT_G16VK7FR
# BS_XNYQS1WG  Female               PT_G16VK7FR
# BS_CGXTFM67  Female               PT_M23Q0DC3
# BS_XQF18WZP    Male               PT_RE6AXQM1
#
#                                                  disease_type  sample_id
# BS_EBCJ4Y49                                 Craniopharyngioma  7316-3766  \
# BS_C3KDA5ZC        Dysplasia/Gliosis;Glial-neuronal tumor NOS  7316-2856
# BS_HNE6BPMH                                Germinoma;Teratoma  7316-3892
# BS_F8K4VQMF                               Gliomatosis Cerebri  7316-3817
# BS_1YTHM07J  High-grade glioma/astrocytoma (WHO grade III/IV)   7316-325
# ...                                                       ...        ...
# BS_AH3RVK53                                               NaN    SF11385
# BS_JEZBA2EW                                               NaN  CNMC-1277
# BS_XNYQS1WG                                               NaN  7316-5814
# BS_CGXTFM67                                               NaN  7316-3212
# BS_XQF18WZP                                               NaN  7316-5813
#
#               Tumor Descriptor                      primary_site_x
# BS_EBCJ4Y49         Recurrence  Suprasellar/Hypothalamic/Pituitary  \
# BS_C3KDA5ZC  Initial CNS Tumor                        Frontal Lobe
# BS_HNE6BPMH        Progressive                        Pineal Gland
# BS_F8K4VQMF  Initial CNS Tumor                        Frontal Lobe
# BS_1YTHM07J         Recurrence          Cerebellum/Posterior Fossa
# ...                        ...                                 ...
# BS_AH3RVK53          Diagnosis                                 NaN
# BS_JEZBA2EW          Diagnosis                                 NaN
# BS_XNYQS1WG          Diagnosis                                 NaN
# BS_CGXTFM67          Diagnosis                                 NaN
# BS_XQF18WZP          Diagnosis                                 NaN
#
#              age_at_diagnosis aliquot_id Kids_First_Participant_ID
# BS_EBCJ4Y49              3934        NaN                       NaN  \
# BS_C3KDA5ZC              6251    1115259               PT_YQWG98Z5
# BS_HNE6BPMH              6196    1115244               PT_V5ASTHRH
# BS_F8K4VQMF              4599    1114570               PT_J5NSRW1Y
# BS_1YTHM07J              7464     577729               PT_279D9QZ8
# ...                       ...        ...                       ...
# BS_AH3RVK53              3159        NaN                       NaN
# BS_JEZBA2EW              2021        NaN                       NaN
# BS_XNYQS1WG              2021     A19681               PT_G16VK7FR
# BS_CGXTFM67              1740     A04015               PT_M23Q0DC3
# BS_XQF18WZP              1743     A19019               PT_RE6AXQM1
#
#             sample_type   tumor_descriptor              primary_site_y
# BS_EBCJ4Y49         NaN                NaN                         NaN  \
# BS_C3KDA5ZC       Tumor  Initial CNS Tumor                Frontal Lobe
# BS_HNE6BPMH       Tumor        Progressive                Pineal Gland
# BS_F8K4VQMF       Tumor  Initial CNS Tumor                Frontal Lobe
# BS_1YTHM07J       Tumor         Recurrence  Cerebellum/Posterior Fossa
# ...                 ...                ...                         ...
# BS_AH3RVK53         NaN                NaN                         NaN
# BS_JEZBA2EW         NaN                NaN                         NaN
# BS_XNYQS1WG       Tumor  Initial CNS Tumor              Pons/Brainstem
# BS_CGXTFM67       Tumor  Initial CNS Tumor              Pons/Brainstem
# BS_XQF18WZP       Tumor  Initial CNS Tumor              Pons/Brainstem
#
#             reported_gender                       race
# BS_EBCJ4Y49             NaN                        NaN  \
# BS_C3KDA5ZC            Male  Black or African American
# BS_HNE6BPMH            Male           Reported Unknown
# BS_F8K4VQMF            Male  Black or African American
# BS_1YTHM07J          Female                      White
# ...                     ...                        ...
# BS_AH3RVK53             NaN                        NaN
# BS_JEZBA2EW             NaN                        NaN
# BS_XNYQS1WG          Female           Reported Unknown
# BS_CGXTFM67          Female           Reported Unknown
# BS_XQF18WZP            Male                      White
#
#                           ethnicity  age_at_diagnosis_days
# BS_EBCJ4Y49                     NaN                    NaN  \
# BS_C3KDA5ZC  Not Hispanic or Latino                 6251.0
# BS_HNE6BPMH  Not Hispanic or Latino                 6116.0
# BS_F8K4VQMF  Not Hispanic or Latino                 4599.0
# BS_1YTHM07J  Not Hispanic or Latino                 5859.0
# ...                             ...                    ...
# BS_AH3RVK53                     NaN                    NaN
# BS_JEZBA2EW                     NaN                    NaN
# BS_XNYQS1WG  Not Hispanic or Latino                 2021.0
# BS_CGXTFM67  Not Hispanic or Latino                 1740.0
# BS_XQF18WZP  Not Hispanic or Latino                 1743.0
#
#                                            pathology_diagnosis RNA_library
# BS_EBCJ4Y49                                                NaN         NaN  \
# BS_C3KDA5ZC                                  Dysplasia/Gliosis         NaN
# BS_HNE6BPMH                              Mixed germ cell tumor         NaN
# BS_F8K4VQMF   High-grade glioma/astrocytoma (WHO grade III/IV)         NaN
# BS_1YTHM07J                                      Ganglioglioma    stranded
# ...                                                        ...         ...
# BS_AH3RVK53                                                NaN         NaN
# BS_JEZBA2EW                                                NaN         NaN
# BS_XNYQS1WG  Brainstem glioma- Diffuse intrinsic pontine gl...         NaN
# BS_CGXTFM67  Brainstem glioma- Diffuse intrinsic pontine gl...         NaN
# BS_XQF18WZP  Brainstem glioma- Diffuse intrinsic pontine gl...         NaN
#
#              OS_days OS_status  EFS_days cohort  age_last_update_days
# BS_EBCJ4Y49      NaN       NaN       NaN    NaN                   NaN  \
# BS_C3KDA5ZC    411.0    LIVING     411.0   PBTA                6662.0
# BS_HNE6BPMH   1660.0    LIVING      80.0   PBTA                7776.0
# BS_F8K4VQMF    492.0  DECEASED     373.0   PBTA                5091.0
# BS_1YTHM07J   3011.0    LIVING     202.0   PBTA                8870.0
# ...              ...       ...       ...    ...                   ...
# BS_AH3RVK53      NaN       NaN       NaN    NaN                   NaN
# BS_JEZBA2EW      NaN       NaN       NaN    NaN                   NaN
# BS_XNYQS1WG    150.0  DECEASED       NaN   PBTA                2171.0
# BS_CGXTFM67    882.0  DECEASED       NaN   PBTA                2622.0
# BS_XQF18WZP    346.0  DECEASED       NaN   PBTA                2089.0
#
#                          seq_center cancer_predispositions
# BS_EBCJ4Y49                     NaN                    NaN  \
# BS_C3KDA5ZC                     NaN        None documented
# BS_HNE6BPMH                     NaN        None documented
# BS_F8K4VQMF                     NaN        None documented
# BS_1YTHM07J               NantOmics        None documented
# ...                             ...                    ...
# BS_AH3RVK53                     NaN                    NaN
# BS_JEZBA2EW                     NaN                    NaN
# BS_XNYQS1WG  BGI@CHOP Genome Center        None documented
# BS_CGXTFM67               NantOmics        None documented
# BS_XQF18WZP  BGI@CHOP Genome Center        None documented
#
#                                  pathology_free_text_diagnosis
# BS_EBCJ4Y49                                                NaN  \
# BS_C3KDA5ZC                     neuroglial tissue with gliosis
# BS_HNE6BPMH                                 Germinoma;Teratoma
# BS_F8K4VQMF         glioblastoma, idh-1 negative, who grade iv
# BS_1YTHM07J                                      ganglioglioma
# ...                                                        ...
# BS_AH3RVK53                                                NaN
# BS_JEZBA2EW                                                NaN
# BS_XNYQS1WG  Diffuse midline glioma, H3K27M mutant, WHO gra...
# BS_CGXTFM67                                Diffuse Astrocytoma
# BS_XQF18WZP                                Diffuse Astrocytoma
#
#             cohort_participant_id   extent_of_tumor_resection
# BS_EBCJ4Y49                   NaN                         NaN  \
# BS_C3KDA5ZC               C789045  Gross/Near total resection
# BS_HNE6BPMH              C1028157  Gross/Near total resection
# BS_F8K4VQMF               C992733           Partial resection
# BS_1YTHM07J                C17712  Gross/Near total resection
# ...                           ...                         ...
# BS_AH3RVK53                   NaN                         NaN
# BS_JEZBA2EW                   NaN                         NaN
# BS_XNYQS1WG              C3093696                         NaN
# BS_CGXTFM67               C956940                         NaN
# BS_XQF18WZP              C3093573                         NaN
#
#                   CNS_region  gtex_group  gtex_subgroup germline_sex_estimate
# BS_EBCJ4Y49              NaN         NaN            NaN                   NaN  \
# BS_C3KDA5ZC      Hemispheric         NaN            NaN                  Male
# BS_HNE6BPMH          Midline         NaN            NaN                  Male
# BS_F8K4VQMF      Hemispheric         NaN            NaN                  Male
# BS_1YTHM07J  Posterior fossa         NaN            NaN                Female
# ...                      ...         ...            ...                   ...
# BS_AH3RVK53              NaN         NaN            NaN                   NaN
# BS_JEZBA2EW              NaN         NaN            NaN                   NaN
# BS_XNYQS1WG          Midline         NaN            NaN                Female
# BS_CGXTFM67          Midline         NaN            NaN                Female
# BS_XQF18WZP          Midline         NaN            NaN               Unknown
#
#              normal_fraction  tumor_fraction  tumor_ploidy  age_at_event_days
# BS_EBCJ4Y49              NaN             NaN           NaN                NaN  \
# BS_C3KDA5ZC              NaN             NaN           NaN             6251.0
# BS_HNE6BPMH              NaN             NaN           NaN             6196.0
# BS_F8K4VQMF              NaN             NaN           NaN             4599.0
# BS_1YTHM07J              NaN             NaN           NaN             7464.0
# ...                      ...             ...           ...                ...
# BS_AH3RVK53              NaN             NaN           NaN                NaN
# BS_JEZBA2EW              NaN             NaN           NaN                NaN
# BS_XNYQS1WG         0.189144        0.810856           2.0             2021.0
# BS_CGXTFM67         0.000000        1.000000           2.0             1740.0
# BS_XQF18WZP         0.576807        0.423193           2.0             1743.0
#
#             clinical_status_at_event  age_at_chemo_start
# BS_EBCJ4Y49                      NaN                 NaN  \
# BS_C3KDA5ZC                    Alive                 NaN
# BS_HNE6BPMH                    Alive              6215.0
# BS_F8K4VQMF                    Alive              5021.0
# BS_1YTHM07J                    Alive              5862.0
# ...                              ...                 ...
# BS_AH3RVK53                      NaN                 NaN
# BS_JEZBA2EW                      NaN                 NaN
# BS_XNYQS1WG                      NaN                 NaN
# BS_CGXTFM67                      NaN                 NaN
# BS_XQF18WZP                      NaN                 NaN
#
#              age_at_radiation_start cell_line_composition  cell_line_passage
# BS_EBCJ4Y49                     NaN                   NaN                NaN  \
# BS_C3KDA5ZC                     NaN                   NaN                NaN
# BS_HNE6BPMH                     NaN                   NaN                NaN
# BS_F8K4VQMF                  4625.0                   NaN                NaN
# BS_1YTHM07J                     NaN                   NaN                NaN
# ...                             ...                   ...                ...
# BS_AH3RVK53                     NaN                   NaN                NaN
# BS_JEZBA2EW                     NaN                   NaN                NaN
# BS_XNYQS1WG                     NaN                   NaN                NaN
# BS_CGXTFM67                     NaN                   NaN                NaN
# BS_XQF18WZP                     NaN                   NaN                NaN
#
#              tumor_fraction_RFpurify_ABSOLUTE
# BS_EBCJ4Y49                               NaN  \
# BS_C3KDA5ZC                          0.556153
# BS_HNE6BPMH                          0.291384
# BS_F8K4VQMF                          0.664495
# BS_1YTHM07J                               NaN
# ...                                       ...
# BS_AH3RVK53                               NaN
# BS_JEZBA2EW                               NaN
# BS_XNYQS1WG                               NaN
# BS_CGXTFM67                               NaN
# BS_XQF18WZP                               NaN
#
#              tumor_fraction_RFpurify_ESTIMATE  tumor_fraction_LUMP
# BS_EBCJ4Y49                               NaN                  NaN  \
# BS_C3KDA5ZC                          0.889237             0.836663
# BS_HNE6BPMH                          0.522747             0.118345
# BS_F8K4VQMF                          0.920429             0.806252
# BS_1YTHM07J                               NaN                  NaN
# ...                                       ...                  ...
# BS_AH3RVK53                               NaN                  NaN
# BS_JEZBA2EW                               NaN                  NaN
# BS_XNYQS1WG                               NaN                  NaN
# BS_CGXTFM67                               NaN                  NaN
# BS_XQF18WZP                               NaN                  NaN
#
#             dkfz_v11_methylation_subclass
# BS_EBCJ4Y49                           NaN  \
# BS_C3KDA5ZC                     CONTR, WM
# BS_HNE6BPMH                 CONTR, INFLAM
# BS_F8K4VQMF                  GBM, RTK III
# BS_1YTHM07J                           NaN
# ...                                   ...
# BS_AH3RVK53                           NaN
# BS_JEZBA2EW                           NaN
# BS_XNYQS1WG                           NaN
# BS_CGXTFM67                           NaN
# BS_XQF18WZP                           NaN
#
#              dkfz_v11_methylation_subclass_score
# BS_EBCJ4Y49                                  NaN  \
# BS_C3KDA5ZC                                0.483
# BS_HNE6BPMH                                0.187
# BS_F8K4VQMF                                1.000
# BS_1YTHM07J                                  NaN
# ...                                          ...
# BS_AH3RVK53                                  NaN
# BS_JEZBA2EW                                  NaN
# BS_XNYQS1WG                                  NaN
# BS_CGXTFM67                                  NaN
# BS_XQF18WZP                                  NaN
#
#             dkfz_v12_methylation_subclass
# BS_EBCJ4Y49                           NaN  \
# BS_C3KDA5ZC                  CTRL_CORPCAL
# BS_HNE6BPMH                    GCT_GERM_A
# BS_F8K4VQMF                  pedHGG_RTK2A
# BS_1YTHM07J                           NaN
# ...                                   ...
# BS_AH3RVK53                           NaN
# BS_JEZBA2EW                           NaN
# BS_XNYQS1WG                           NaN
# BS_CGXTFM67                           NaN
# BS_XQF18WZP                           NaN
#
#              dkfz_v12_methylation_subclass_score
# BS_EBCJ4Y49                                  NaN  \
# BS_C3KDA5ZC                             0.999737
# BS_HNE6BPMH                             0.830271
# BS_F8K4VQMF                             0.999860
# BS_1YTHM07J                                  NaN
# ...                                          ...
# BS_AH3RVK53                                  NaN
# BS_JEZBA2EW                                  NaN
# BS_XNYQS1WG                                  NaN
# BS_CGXTFM67                                  NaN
# BS_XQF18WZP                                  NaN
#
#             dkfz_v12_methylation_mgmt_status
# BS_EBCJ4Y49                              NaN  \
# BS_C3KDA5ZC                     unmethylated
# BS_HNE6BPMH                       methylated
# BS_F8K4VQMF                     unmethylated
# BS_1YTHM07J                              NaN
# ...                                      ...
# BS_AH3RVK53                              NaN
# BS_JEZBA2EW                              NaN
# BS_XNYQS1WG                              NaN
# BS_CGXTFM67                              NaN
# BS_XQF18WZP                              NaN
#
#              dkfz_v12_methylation_mgmt_estimated  molecular_subtype
# BS_EBCJ4Y49                                  NaN                NaN  \
# BS_C3KDA5ZC                             0.153483                NaN
# BS_HNE6BPMH                             0.449330                NaN
# BS_F8K4VQMF                             0.000808   HGG, H3 wildtype
# BS_1YTHM07J                                  NaN      GNG, wildtype
# ...                                          ...                ...
# BS_AH3RVK53                                  NaN                NaN
# BS_JEZBA2EW                                  NaN                NaN
# BS_XNYQS1WG                                  NaN  DMG, H3 K28, TP53
# BS_CGXTFM67                                  NaN        DMG, H3 K28
# BS_XQF18WZP                                  NaN  DMG, H3 K28, TP53
#
#                                         integrated_diagnosis
# BS_EBCJ4Y49                                              NaN  \
# BS_C3KDA5ZC                                              NaN
# BS_HNE6BPMH                                              NaN
# BS_F8K4VQMF  High-grade glioma, IDH-wildtype and H3-wildtype
# BS_1YTHM07J                          Ganglioglioma, wildtype
# ...                                                      ...
# BS_AH3RVK53                                              NaN
# BS_JEZBA2EW                                              NaN
# BS_XNYQS1WG            Diffuse midline glioma, H3 K28-mutant
# BS_CGXTFM67            Diffuse midline glioma, H3 K28-mutant
# BS_XQF18WZP            Diffuse midline glioma, H3 K28-mutant
#
#                                         Notes
# BS_EBCJ4Y49                               NaN  \
# BS_C3KDA5ZC                               NaN
# BS_HNE6BPMH                               NaN
# BS_F8K4VQMF  Updated via OpenPedCan subtyping
# BS_1YTHM07J  Updated via OpenPedCan subtyping
# ...                                       ...
# BS_AH3RVK53                               NaN
# BS_JEZBA2EW                               NaN
# BS_XNYQS1WG  Updated via OpenPedCan subtyping
# BS_CGXTFM67  Updated via OpenPedCan subtyping
# BS_XQF18WZP  Updated via OpenPedCan subtyping
#
#                                         harmonized_diagnosis
# BS_EBCJ4Y49                                              NaN  \
# BS_C3KDA5ZC                                Dysplasia/Gliosis
# BS_HNE6BPMH                            Mixed germ cell tumor
# BS_F8K4VQMF  High-grade glioma, IDH-wildtype and H3-wildtype
# BS_1YTHM07J                          Ganglioglioma, wildtype
# ...                                                      ...
# BS_AH3RVK53                                              NaN
# BS_JEZBA2EW                                              NaN
# BS_XNYQS1WG            Diffuse midline glioma, H3 K28-mutant
# BS_CGXTFM67            Diffuse midline glioma, H3 K28-mutant
# BS_XQF18WZP            Diffuse midline glioma, H3 K28-mutant
#
#             molecular_subtype_methyl
# BS_EBCJ4Y49                      NaN  \
# BS_C3KDA5ZC                      NaN
# BS_HNE6BPMH                      NaN
# BS_F8K4VQMF         HGG, H3 wildtype
# BS_1YTHM07J                      NaN
# ...                              ...
# BS_AH3RVK53                      NaN
# BS_JEZBA2EW                      NaN
# BS_XNYQS1WG                      NaN
# BS_CGXTFM67                      NaN
# BS_XQF18WZP                      NaN
#
#                                            broad_histology  short_histology
# BS_EBCJ4Y49                                            NaN              NaN  \
# BS_C3KDA5ZC                           Pre-cancerous lesion        Dysplasia
# BS_HNE6BPMH                                Germ cell tumor  Germ cell tumor
# BS_F8K4VQMF  Diffuse astrocytic and oligodendroglial tumor             HGAT
# BS_1YTHM07J                     Low-grade astrocytic tumor    Ganglioglioma
# ...                                                    ...              ...
# BS_AH3RVK53                                            NaN              NaN
# BS_JEZBA2EW                                            NaN              NaN
# BS_XNYQS1WG  Diffuse astrocytic and oligodendroglial tumor             HGAT
# BS_CGXTFM67  Diffuse astrocytic and oligodendroglial tumor             HGAT
# BS_XQF18WZP  Diffuse astrocytic and oligodendroglial tumor             HGAT
#
#                        cancer_group
# BS_EBCJ4Y49                     NaN
# BS_C3KDA5ZC                     NaN
# BS_HNE6BPMH   Mixed germ cell tumor
# BS_F8K4VQMF       High-grade glioma
# BS_1YTHM07J           Ganglioglioma
# ...                             ...
# BS_AH3RVK53                     NaN
# BS_JEZBA2EW                     NaN
# BS_XNYQS1WG  Diffuse midline glioma
# BS_CGXTFM67  Diffuse midline glioma
# BS_XQF18WZP  Diffuse midline glioma
#
# [113 rows x 58 columns]

# %%
df.gender.unique()
# Out:
# array(['Female', 'Male', 'Not Reported'], dtype=object)

# %%
def compare(df,left,right):
    print(f"NA values in {left}: {df[left].isna().sum()}")
    print(f"NA values in {right}: {df[right].isna().sum()}")
    print(f"NA values in both: {(df[left].isna() & df[right].isna()).sum()}")
    print(f"Different values: {((df[left] != df[right]) & (~df[left].isna()) & (~df[right].isna())).sum()}")
    return df[((df[left] != df[right]) & (~df[left].isna()) & (~df[right].isna()))]
compare(df,"age_at_diagnosis","age_at_diagnosis_days")
compare(df,"disease_type","pathology_diagnosis")
compare(df,"gender","reported_gender")
# Out:
# NA values in age_at_diagnosis: 0
# NA values in age_at_diagnosis_days: 13
# NA values in both: 0
# Different values: 251
# NA values in disease_type: 20
# NA values in pathology_diagnosis: 13
# NA values in both: 3
# Different values: 83
# NA values in gender: 52
# NA values in reported_gender: 13
# NA values in both: 0
# Different values: 2
#             gender Kids First Participant ID       disease_type  sample_id
# BS_969K7ZM1   Male               PT_S2ASFBP7  Craniopharyngioma  7316-2157  \
# BS_XCFNEZ8E   Male               PT_5D3AVPCW  Dysplasia/Gliosis   7316-187
#
#               Tumor Descriptor                             primary_site_x
# BS_969K7ZM1  Initial CNS Tumor         Suprasellar/Hypothalamic/Pituitary  \
# BS_XCFNEZ8E  Initial CNS Tumor  Frontal Lobe;Occipital Lobe;Parietal Lobe
#
#              age_at_diagnosis aliquot_id Kids_First_Participant_ID
# BS_969K7ZM1              3355    1112042               PT_S2ASFBP7  \
# BS_XCFNEZ8E               184    1119219               PT_5D3AVPCW
#
#             sample_type   tumor_descriptor
# BS_969K7ZM1       Tumor  Initial CNS Tumor  \
# BS_XCFNEZ8E       Tumor  Initial CNS Tumor
#
#                                         primary_site_y reported_gender
# BS_969K7ZM1         Suprasellar/Hypothalamic/Pituitary          Female  \
# BS_XCFNEZ8E  Frontal Lobe;Occipital Lobe;Parietal Lobe          Female
#
#                                   race               ethnicity
# BS_969K7ZM1  Black or African American  Not Hispanic or Latino  \
# BS_XCFNEZ8E                      White  Not Hispanic or Latino
#
#              age_at_diagnosis_days pathology_diagnosis RNA_library  OS_days
# BS_969K7ZM1                 3355.0   Craniopharyngioma         NaN   1638.0  \
# BS_XCFNEZ8E                  184.0   Dysplasia/Gliosis         NaN      NaN
#
#             OS_status  EFS_days cohort  age_last_update_days seq_center
# BS_969K7ZM1    LIVING    1638.0   PBTA                4993.0        NaN  \
# BS_XCFNEZ8E    LIVING       NaN   PBTA                 184.0        NaN
#
#             cancer_predispositions pathology_free_text_diagnosis
# BS_969K7ZM1        None documented       craniopharyngioma who i  \
# BS_XCFNEZ8E        None documented             dysplasia/gliosis
#
#             cohort_participant_id   extent_of_tumor_resection   CNS_region
# BS_969K7ZM1               C579945  Gross/Near total resection  Suprasellar  \
# BS_XCFNEZ8E                C42927  Gross/Near total resection  Hemispheric
#
#              gtex_group  gtex_subgroup germline_sex_estimate  normal_fraction
# BS_969K7ZM1         NaN            NaN                Female              NaN  \
# BS_XCFNEZ8E         NaN            NaN                  Male              NaN
#
#              tumor_fraction  tumor_ploidy  age_at_event_days
# BS_969K7ZM1             NaN           NaN             3355.0  \
# BS_XCFNEZ8E             NaN           NaN              184.0
#
#             clinical_status_at_event  age_at_chemo_start
# BS_969K7ZM1                    Alive                 NaN  \
# BS_XCFNEZ8E                    Alive                 NaN
#
#              age_at_radiation_start cell_line_composition  cell_line_passage
# BS_969K7ZM1                     NaN                   NaN                NaN  \
# BS_XCFNEZ8E                     NaN                   NaN                NaN
#
#              tumor_fraction_RFpurify_ABSOLUTE
# BS_969K7ZM1                          0.505627  \
# BS_XCFNEZ8E                          0.496469
#
#              tumor_fraction_RFpurify_ESTIMATE  tumor_fraction_LUMP
# BS_969K7ZM1                          0.829555             0.761779  \
# BS_XCFNEZ8E                          0.863404             0.758558
#
#             dkfz_v11_methylation_subclass
# BS_969K7ZM1                      CPH, ADM  \
# BS_XCFNEZ8E                       LGG, GG
#
#              dkfz_v11_methylation_subclass_score
# BS_969K7ZM1                                0.605  \
# BS_XCFNEZ8E                                0.220
#
#             dkfz_v12_methylation_subclass
# BS_969K7ZM1                       CPH_ADM  \
# BS_XCFNEZ8E                            GG
#
#              dkfz_v12_methylation_subclass_score
# BS_969K7ZM1                             0.355549  \
# BS_XCFNEZ8E                             0.391281
#
#             dkfz_v12_methylation_mgmt_status
# BS_969K7ZM1                     unmethylated  \
# BS_XCFNEZ8E                     unmethylated
#
#              dkfz_v12_methylation_mgmt_estimated molecular_subtype
# BS_969K7ZM1                             0.008309      CRANIO, ADAM  \
# BS_XCFNEZ8E                             0.011750               NaN
#
#                            integrated_diagnosis
# BS_969K7ZM1  Adamantinomatous craniopharyngioma  \
# BS_XCFNEZ8E                                 NaN
#
#                                         Notes
# BS_969K7ZM1  Updated via OpenPedCan subtyping  \
# BS_XCFNEZ8E                               NaN
#
#                            harmonized_diagnosis molecular_subtype_methyl
# BS_969K7ZM1  Adamantinomatous craniopharyngioma                      NaN  \
# BS_XCFNEZ8E                   Dysplasia/Gliosis                      NaN
#
#                      broad_histology    short_histology
# BS_969K7ZM1  Tumors of sellar region  Craniopharyngioma  \
# BS_XCFNEZ8E     Pre-cancerous lesion          Dysplasia
#
#                                    cancer_group
# BS_969K7ZM1  Adamantinomatous Craniopharyngioma
# BS_XCFNEZ8E                                 NaN

# %%
def generate_sj_biosample_table():
    '''
    Notes:
    sj_diseases != attr_oncotree_disease_code = sj_associated_diagnoses_disease_code
    attr_diagnosis != sj_long_disease_name != sj_associated_diagnoses
    TODO:
    Add coarse tumor types as sunita's data.
    '''
    df = pd.DataFrame(index=get_pedpancan_biosamples_from_AC())
    columns = ['subject_name','sample_type','attr_age_at_diagnosis','attr_sex','sj_long_disease_name','sj_diseases','sj_dataset_accessions']
    add = import_sj_sample_info()[columns]
    add = add.sort_values(columns)
    add = add.loc[~add.index.duplicated()]
    df = pd.merge(left=df,how='inner',right=add, left_index=True, right_index=True)
    return df
b=generate_sj_biosample_table()
# Setup the output directory
OUT_DIR = pathlib.Path(pathlib.Path.cwd(),"out")
def makedirs(path):
    if not os.path.exists(path):
        # Create the directory
        os.makedirs(path)
makedirs(OUT_DIR)
b.to_csv(pathlib.Path(OUT_DIR,"sj_biosamples.tsv"), sep='\t')

# %%
c = import_sunita_sj_master_table()
c
# Out:
#                Survival Status Date of Primary Dx Date of Death
# Sample_ID
# SJACT001_D                 NaN                NaT           NaT  \
# SJACT001_G                 NaN                NaT           NaT
# SJACT002_D                 NaN                NaT           NaT
# SJACT002_G                 NaN                NaT           NaT
# SJACT003_D                 NaN                NaT           NaT
# ...                        ...                ...           ...
# SJWLM031171_G1             NaN                NaT           NaT
# SJWLM031295_D1           Alive         2018-09-07           NaT
# SJWLM031295_G1             NaN                NaT           NaT
# SJWLM031308_D1           Alive         2019-04-04           NaT
# SJWLM031308_G1             NaN                NaT           NaT
#
#                Overall Survival in Months Most Recent Dx
# Sample_ID
# SJACT001_D                            NaN            NaT  \
# SJACT001_G                            NaN            NaT
# SJACT002_D                            NaN            NaT
# SJACT002_G                            NaN            NaT
# SJACT003_D                            NaN            NaT
# ...                                   ...            ...
# SJWLM031171_G1                        NaN            NaT
# SJWLM031295_D1                       50.2     2018-09-07
# SJWLM031295_G1                        NaN            NaT
# SJWLM031308_D1                  43.233333     2019-04-04
# SJWLM031308_G1                        NaN            NaT
#
#                Survival  in Months since most recent Dx
# Sample_ID
# SJACT001_D                                          NaN  \
# SJACT001_G                                          NaN
# SJACT002_D                                          NaN
# SJACT002_G                                          NaN
# SJACT003_D                                          NaN
# ...                                                 ...
# SJWLM031171_G1                                      NaN
# SJWLM031295_D1                                     50.2
# SJWLM031295_G1                                      NaN
# SJWLM031308_D1                                43.233333
# SJWLM031308_G1                                      NaN
#
#                Date of data collection
# Sample_ID
# SJACT001_D                         NaT
# SJACT001_G                         NaT
# SJACT002_D                         NaT
# SJACT002_G                         NaT
# SJACT003_D                         NaT
# ...                                ...
# SJWLM031171_G1                     NaT
# SJWLM031295_D1              2022-10-22
# SJWLM031295_G1                     NaT
# SJWLM031308_D1              2022-10-22
# SJWLM031308_G1                     NaT
#
# [5240 rows x 7 columns]

# %%
# Ependymomas with RNA-seq and survival data
df = import_opentarget_histologies_files()
df[(df.pathology_diagnosis=="Ependymoma") & (~df.OS_days.isna()) & (df.experimental_strategy == 'RNA-Seq')]
# Out:
# /var/folders/mz/x6bkt9t91j598wz6hnwc7b2m0000gp/T/ipykernel_41693/3614857803.py:49: DtypeWarning: Columns (1,21,24,25,26,27,33,36,37,41,43,45,47,48,49,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path,sep='\t')
#       Kids_First_Biospecimen_ID  sample_id aliquot_id
# 9                   BS_00W5QB9S  7316-6972    1202560  \
# 76                  BS_07ANYSYQ  7316-2134     571441
# 115                 BS_0BXY0F9N  7316-1078     588352
# 228                 BS_0QYS36NR   7316-455     588317
# 285                 BS_0WQJP6ZG   7316-425     470441
# ...                         ...        ...        ...
# 10137               BS_YE1MAQYJ  7316-3319     711675
# 10413               BS_Z7890YNR   7316-451     571397
# 10463               BS_ZC1194Z8  7316-7959    1202538
# 10521               BS_ZJC7VQNA  7316-6143    1202555
# 10655               BS_ZYVWSXNK  7316-6975    1202508
#
#       Kids_First_Participant_ID experimental_strategy sample_type
# 9                   PT_K84J9401               RNA-Seq       Tumor  \
# 76                  PT_S4H6KA09               RNA-Seq       Tumor
# 115                 PT_164RNWTT               RNA-Seq       Tumor
# 228                 PT_V3Q78E6F               RNA-Seq       Tumor
# 285                 PT_Y6Y9JJ9P               RNA-Seq       Tumor
# ...                         ...                   ...         ...
# 10137               PT_ZZRBX5JT               RNA-Seq       Tumor
# 10413               PT_99S5BPE3               RNA-Seq       Tumor
# 10463               PT_X7GTQR9N               RNA-Seq       Tumor
# 10521               PT_6N4TJ9G3               RNA-Seq       Tumor
# 10655               PT_VG6S9YQ9               RNA-Seq       Tumor
#
#         composition   tumor_descriptor
# 9      Solid Tissue        Progressive  \
# 76     Solid Tissue  Initial CNS Tumor
# 115    Solid Tissue  Initial CNS Tumor
# 228    Solid Tissue  Initial CNS Tumor
# 285    Solid Tissue        Progressive
# ...             ...                ...
# 10137  Solid Tissue         Recurrence
# 10413  Solid Tissue         Recurrence
# 10463  Solid Tissue  Initial CNS Tumor
# 10521  Solid Tissue  Initial CNS Tumor
# 10655  Solid Tissue         Recurrence
#
#                                    primary_site reported_gender   race
# 9                    Cerebellum/Posterior Fossa            Male  Asian  \
# 76                                 Frontal Lobe          Female  White
# 115                  Cerebellum/Posterior Fossa            Male  Asian
# 228                                  Ventricles          Female  White
# 285                                Frontal Lobe          Female  Asian
# ...                                         ...             ...    ...
# 10137            Spinal Cord- Lumbar/Thecal Sac          Female  White
# 10413  Frontal Lobe;Parietal Lobe;Temporal Lobe            Male  White
# 10463     Cerebellum/Posterior Fossa;Ventricles          Female  White
# 10521                                Ventricles            Male  White
# 10655                                Ventricles            Male  Asian
#
#                     ethnicity  age_at_diagnosis_days pathology_diagnosis
# 9      Not Hispanic or Latino                 3192.0          Ependymoma  \
# 76     Not Hispanic or Latino                 1412.0          Ependymoma
# 115    Not Hispanic or Latino                 2549.0          Ependymoma
# 228        Hispanic or Latino                  337.0          Ependymoma
# 285               Unavailable                 2271.0          Ependymoma
# ...                       ...                    ...                 ...
# 10137  Not Hispanic or Latino                 1878.0          Ependymoma
# 10413  Not Hispanic or Latino                 6695.0          Ependymoma
# 10463  Not Hispanic or Latino                 1014.0          Ependymoma
# 10521  Not Hispanic or Latino                 6673.0          Ependymoma
# 10655  Not Hispanic or Latino                  592.0          Ependymoma
#
#            RNA_library  OS_days OS_status  EFS_days cohort
# 9      poly-A stranded   1054.0    LIVING     192.0   PBTA  \
# 76            stranded   2225.0    LIVING    1090.0   PBTA
# 115           stranded    560.0    LIVING     560.0   PBTA
# 228           stranded    416.0    LIVING     416.0   PBTA
# 285           stranded    882.0  DECEASED     385.0   PBTA
# ...                ...      ...       ...       ...    ...
# 10137         stranded   1963.0    LIVING     789.0   PBTA
# 10413         stranded   2066.0  DECEASED     629.0   PBTA
# 10463  poly-A stranded    734.0    LIVING     734.0   PBTA
# 10521  poly-A stranded    917.0    LIVING     917.0   PBTA
# 10655  poly-A stranded   5679.0    LIVING    5134.0   PBTA
#
#        age_last_update_days              seq_center
# 9                    4246.0                     NaN  \
# 76                   3637.0               NantOmics
# 115                  3109.0               NantOmics
# 228                   753.0               NantOmics
# 285                  3153.0  BGI@CHOP Genome Center
# ...                     ...                     ...
# 10137                3841.0               NantOmics
# 10413                8761.0               NantOmics
# 10463                1748.0                     NaN
# 10521                7590.0                     NaN
# 10655                6271.0                     NaN
#
#                cancer_predispositions
# 9                     None documented  \
# 76                    None documented
# 115                   None documented
# 228                   None documented
# 285                   None documented
# ...                               ...
# 10137                 None documented
# 10413                 None documented
# 10463                 None documented
# 10521  Other inherited conditions NOS
# 10655                 None documented
#
#                         pathology_free_text_diagnosis cohort_participant_id
# 9                anaplastic ependymoma, who grade iii              C2803539  \
# 76                anaplastic ependymoma who grade iii               C522750
# 115                   ependymoma grade iii anaplastic               C291633
# 228                                        ependymoma                C96309
# 285                     anaplastic ependymoma who iii               C657435
# ...                                               ...                   ...
# 10137                                      ependymoma               C121647
# 10413                                      ependymoma                C20172
# 10463   posterior fossa ependymoma group pfa (by ihc)              C3512757
# 10521                        ependymoma, who grade ii              C2694930
# 10655  ependymoma, rela fusion positive, who grade ii              C2899233
#
#         extent_of_tumor_resection       CNS_region gtex_group gtex_subgroup
# 9      Gross/Near total resection  Posterior fossa        NaN           NaN  \
# 76     Gross/Near total resection      Hemispheric        NaN           NaN
# 115             Partial resection  Posterior fossa        NaN           NaN
# 228             Partial resection       Ventricles        NaN           NaN
# 285    Gross/Near total resection      Hemispheric        NaN           NaN
# ...                           ...              ...        ...           ...
# 10137  Gross/Near total resection            Spine        NaN           NaN
# 10413           Partial resection      Hemispheric        NaN           NaN
# 10463  Gross/Near total resection            Mixed        NaN           NaN
# 10521  Gross/Near total resection       Ventricles        NaN           NaN
# 10655  Gross/Near total resection       Ventricles        NaN           NaN
#
#       germline_sex_estimate  normal_fraction  tumor_fraction  tumor_ploidy
# 9                      Male              NaN             NaN           NaN  \
# 76                   Female              NaN             NaN           NaN
# 115                    Male              NaN             NaN           NaN
# 228                  Female              NaN             NaN           NaN
# 285                     NaN              NaN             NaN           NaN
# ...                     ...              ...             ...           ...
# 10137                Female              NaN             NaN           NaN
# 10413                  Male              NaN             NaN           NaN
# 10463                Female              NaN             NaN           NaN
# 10521                  Male              NaN             NaN           NaN
# 10655                  Male              NaN             NaN           NaN
#
#        age_at_event_days clinical_status_at_event  age_at_chemo_start
# 9                 3384.0                    Alive              3482.0  \
# 76                1412.0                    Alive                 NaN
# 115               2549.0                    Alive                 NaN
# 228                337.0                    Alive                 NaN
# 285               3013.0                    Alive              3028.0
# ...                  ...                      ...                 ...
# 10137             2967.0                    Alive              3332.0
# 10413             8339.0                    Alive              7362.0
# 10463             1014.0                    Alive              1119.0
# 10521             6673.0                    Alive                 NaN
# 10655             5726.0                    Alive                 NaN
#
#        age_at_radiation_start cell_line_composition cell_line_passage
# 9                      3419.0                   NaN               NaN  \
# 76                     1460.0                   NaN               NaN
# 115                       NaN                   NaN               NaN
# 228                     377.0                   NaN               NaN
# 285                    2696.0                   NaN               NaN
# ...                       ...                   ...               ...
# 10137                  3295.0                   NaN               NaN
# 10413                  6724.0                   NaN               NaN
# 10463                  1044.0                   NaN               NaN
# 10521                     NaN                   NaN               NaN
# 10655                     NaN                   NaN               NaN
#
#        tumor_fraction_RFpurify_ABSOLUTE  tumor_fraction_RFpurify_ESTIMATE
# 9                                   NaN                               NaN  \
# 76                                  NaN                               NaN
# 115                                 NaN                               NaN
# 228                                 NaN                               NaN
# 285                                 NaN                               NaN
# ...                                 ...                               ...
# 10137                               NaN                               NaN
# 10413                               NaN                               NaN
# 10463                               NaN                               NaN
# 10521                               NaN                               NaN
# 10655                               NaN                               NaN
#
#        tumor_fraction_LUMP dkfz_v11_methylation_subclass
# 9                      NaN                           NaN  \
# 76                     NaN                           NaN
# 115                    NaN                           NaN
# 228                    NaN                           NaN
# 285                    NaN                           NaN
# ...                    ...                           ...
# 10137                  NaN                           NaN
# 10413                  NaN                           NaN
# 10463                  NaN                           NaN
# 10521                  NaN                           NaN
# 10655                  NaN                           NaN
#
#        dkfz_v11_methylation_subclass_score dkfz_v12_methylation_subclass
# 9                                      NaN                           NaN  \
# 76                                     NaN                           NaN
# 115                                    NaN                           NaN
# 228                                    NaN                           NaN
# 285                                    NaN                           NaN
# ...                                    ...                           ...
# 10137                                  NaN                           NaN
# 10413                                  NaN                           NaN
# 10463                                  NaN                           NaN
# 10521                                  NaN                           NaN
# 10655                                  NaN                           NaN
#
#        dkfz_v12_methylation_subclass_score dkfz_v12_methylation_mgmt_status
# 9                                      NaN                              NaN  \
# 76                                     NaN                              NaN
# 115                                    NaN                              NaN
# 228                                    NaN                              NaN
# 285                                    NaN                              NaN
# ...                                    ...                              ...
# 10137                                  NaN                              NaN
# 10413                                  NaN                              NaN
# 10463                                  NaN                              NaN
# 10521                                  NaN                              NaN
# 10655                                  NaN                              NaN
#
#        dkfz_v12_methylation_mgmt_estimated      molecular_subtype
# 9                                      NaN  EPN, To be classified  \
# 76                                     NaN           EPN, ST ZFTA
# 115                                    NaN              EPN, PF A
# 228                                    NaN  EPN, To be classified
# 285                                    NaN           EPN, ST ZFTA
# ...                                    ...                    ...
# 10137                                  NaN              EPN, PF A
# 10413                                  NaN           EPN, ST ZFTA
# 10463                                  NaN              EPN, PF A
# 10521                                  NaN              EPN, PF B
# 10655                                  NaN           EPN, ST ZFTA
#
#                                   integrated_diagnosis
# 9                                                  NaN  \
# 76     Supratentorial ependymoma, ZFTA fusion-positive
# 115           Posterior fossa group A (PFA) ependymoma
# 228                                                NaN
# 285    Supratentorial ependymoma, ZFTA fusion-positive
# ...                                                ...
# 10137         Posterior fossa group A (PFA) ependymoma
# 10413  Supratentorial ependymoma, ZFTA fusion-positive
# 10463         Posterior fossa group A (PFA) ependymoma
# 10521         Posterior fossa group B (PFB) ependymoma
# 10655  Supratentorial ependymoma, ZFTA fusion-positive
#
#                                   Notes
# 9                                   NaN  \
# 76     Updated via OpenPedCan subtyping
# 115    Updated via OpenPedCan subtyping
# 228                                 NaN
# 285    Updated via OpenPedCan subtyping
# ...                                 ...
# 10137  Updated via OpenPedCan subtyping
# 10413  Updated via OpenPedCan subtyping
# 10463  Updated via OpenPedCan subtyping
# 10521  Updated via OpenPedCan subtyping
# 10655  Updated via OpenPedCan subtyping
#
#                                   harmonized_diagnosis
# 9                                           Ependymoma  \
# 76     Supratentorial ependymoma, ZFTA fusion-positive
# 115           Posterior fossa group A (PFA) ependymoma
# 228                                         Ependymoma
# 285    Supratentorial ependymoma, ZFTA fusion-positive
# ...                                                ...
# 10137         Posterior fossa group A (PFA) ependymoma
# 10413  Supratentorial ependymoma, ZFTA fusion-positive
# 10463         Posterior fossa group A (PFA) ependymoma
# 10521         Posterior fossa group B (PFB) ependymoma
# 10655  Supratentorial ependymoma, ZFTA fusion-positive
#
#       molecular_subtype_methyl  broad_histology short_histology cancer_group
# 9                          NaN  Ependymal tumor      Ependymoma   Ependymoma
# 76                EPN, ST ZFTA  Ependymal tumor      Ependymoma   Ependymoma
# 115                  EPN, PF A  Ependymal tumor      Ependymoma   Ependymoma
# 228                        NaN  Ependymal tumor      Ependymoma   Ependymoma
# 285               EPN, ST ZFTA  Ependymal tumor      Ependymoma   Ependymoma
# ...                        ...              ...             ...          ...
# 10137                EPN, PF A  Ependymal tumor      Ependymoma   Ependymoma
# 10413             EPN, ST ZFTA  Ependymal tumor      Ependymoma   Ependymoma
# 10463                EPN, PF A  Ependymal tumor      Ependymoma   Ependymoma
# 10521                EPN, PF B  Ependymal tumor      Ependymoma   Ependymoma
# 10655             EPN, ST ZFTA  Ependymal tumor      Ependymoma   Ependymoma
#
# [166 rows x 55 columns]
