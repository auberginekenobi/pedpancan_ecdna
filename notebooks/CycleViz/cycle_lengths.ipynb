# %% [markdown]
# # Get lengths of cycles plotted with CycleViz.
#
# ## Requires:
# - env: py3
# - oscutils: https://github.com/auberginekenobi/oscutils
# - AmpliconArchitect outputs (can be downloaded from AmpliconRepository)

# %%
import pandas
import sys
from pathlib import Path
sys.path.append('/Users/ochapman/projects/oscutils')
import AAutils

# %%
# Input parameters
ROOT=Path('../../data/source/AmpliconArchitect/')
SJRHB031519_path = ROOT/'stjude/results_batch_20240912/SJRHB031519_D1/SJRHB031519_D1_amplicon1_cycles.txt'
SJRHB031519_cycle = 1

# %%
cycle = AAutils.Cycle(SJRHB031519_path.resolve(),SJRHB031519_cycle)
len(cycle) # 669992

# %%
SJHGG052_path = ROOT/'stjude/results_batch_20240912/SJHGG052_A/SJHGG052_A_amplicon1_cycles.txt'
SJHGG052_cycle = 7

# %%
cycle = AAutils.Cycle(SJHGG052_path.resolve(),SJHGG052_cycle)
len(cycle) # 1280956

# %%
BS_M4E4H6NG_path = ROOT/'cbtn/hgg/PT_Y76A7PBA/BS_M4E4H6NG/BS_M4E4H6NG_amplicon1_cycles.txt'
BS_M4E4H6NG_cycle = 2

# %%
cycle = AAutils.Cycle(BS_M4E4H6NG_path.resolve(),BS_M4E4H6NG_cycle)
len(cycle) # 4390545
